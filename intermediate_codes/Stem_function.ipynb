# %%
# -*- coding: utf-8 -*-
#split at ?, । or !
import re
import math
import numpy as np


def tokenize_sentence(text):
    sentences=re.split('(?<=[।?!]) +', text)
    print("Sentences")
    print(sentences)
    return sentences

def tokenize_word(sentences):
    words=[]
    for sentence in sentences:
        words.extend(re.split(', |,| ', sentence))
    print("Words after tokenization")
    print (words)
    return words

def clean_text(words):
    punctuations=r',|\)|\(|\{|\}|\[|\]|\?|\!|।|\‘|\’|\“|\”|\:-|/|—|-'
    numbers = r'[0-9o०१२३४५६७८९]'
    words = [re.sub(numbers, '', i) for i in words]
    words = [re.sub(punctuations, '', i) for i in words]
    #Removing empty strings
    words = [x for x in words if x]
    print("After removing special symbols and numbers")
    print(words)
    return words


def remove_stopwords(words):
    with open('datasets/stopwords.txt',encoding="utf8") as f:
        lines = f.readlines()
    lines = [x.strip() for x in lines]
#     print("Stopwords dataset")
#     print(lines)
    words = [w for w in words if not w in lines]
    print("Words after removing stopwords")
    print(words)
    return words

def preprocess(text):
    sentences=tokenize_sentence(text)
    words=tokenize_word(sentences)
    words=clean_text(words)
    words=remove_stopwords(words)
    return words

def calculate_TF_Dict(doc):
    """ Returns a tf dictionary for each doc whose keys are all
    the unique words in the review and whose values are their
    corresponding tf.
    """
    TF_Dict = {}

    # Total number of terms in the document
    len_of_document = float(len(doc))

    for word in doc:

        # Number of times the term occurs in the document
        term_in_document = doc.count(word)

        #Computes tf for each word
        TF_Dict[word] = term_in_document / len_of_document


    return TF_Dict

def calculate_IDF_Dict():
    """ Returns a dictionary whose keys are all the unique words in the
    dataset and whose values are their corresponding idf.
    """
    countDict = {}
    for word in vocabulary:
        countDict[word]=0
    # Run through each doc's tf dictionary and increment countDict's (word, doc) pair
    for word in vocabulary:
        for doc in range(len(Docs)):
            if word in Docs[doc]:
                countDict[word]+=1


    #Stores the doc count dictionary
    IDF_Dict = {}
    total_num_docs = len(Docs)
    for word in countDict:
        IDF_Dict[word] = 1+math.log(float(total_num_docs) /countDict[word])
    return IDF_Dict

def calculate_TFIDF_Dict(TF_Dict,IDF_Dict):
    """ Returns a dictionary whose keys are all the unique words in the
    review and whose values are their corresponding tfidf.
    """
    TFIDF_Dict = {}
    #For each word in the review, we multiply its tf and its idf.
    for word in TF_Dict:
        TFIDF_Dict[word] = TF_Dict[word] * IDF_Dict[word]
    return TFIDF_Dict


def calculate_TFIDF_Vector(doc):
    TFIDF_Vector = [0.0] * len(vocabulary)
    # For each unique word, if it is in the doc, store its TF-IDF value.
    for i, word in enumerate(vocabulary):
          if word in doc:
                TFIDF_Vector[i] = doc[word]

    return TFIDF_Vector

def create_vector():
    TF_Dict = [calculate_TF_Dict(doc) for doc in Docs]
    IDF_Dict=calculate_IDF_Dict()
    TFIDF_Dict = [calculate_TFIDF_Dict(doc,IDF_Dict) for doc in TF_Dict]
    TFIDF_Vector = [calculate_TFIDF_Vector(doc) for doc in TFIDF_Dict]
    return TFIDF_Vector


def get_jaccard_sim(token1, token2):
    a = set(token1)
    b = set(token2)
    c = a.intersection(b)
    return float(len(c)) / (len(a) + len(b) - len(c))

def get_cosine_sim(a,b):
    a = np.array(a)
    b = np.array(b)
    dot = np.dot(a, b)
    norma = np.linalg.norm(a)
    normb = np.linalg.norm(b)
    cos = dot / (norma * normb)
    return cos

eg1="परिश्रम नगरी हुन्छ? परिश्रम सफलताको ९९ एक-मात्र बाटो हो। जो ९ ९९९ ९९ परिश्रम गर्छ, उही सफल हुन्छ। अब त परिश्रम गर्छौ नि? नगरी कहाँ हुन्छ त!"
tokens1=preprocess(eg1)
eg2="परिश्रम नगरी हुन्छ? परिश्रम सफलताको बाटो हो। जो परिश्रम गर्छ, उही सफल हुन्छ। अब परिश्रम गर्छौ नि? नगरी हुन्छ त!"
tokens2=preprocess(eg2)
print(tokens1)
print(tokens2)
vocabulary=sorted(set(tokens1+tokens2))
Docs=[tokens1,tokens2]
TFIDF_Vector=create_vector()
print(TFIDF_Vector)
jsim=get_jaccard_sim(tokens1,tokens2)
csim=get_cosine_sim(TFIDF_Vector[0],TFIDF_Vector[1])
print(jsim)
print(csim)
# Out:
# Sentences
# ['परिश्रम नगरी हुन्छ?', 'परिश्रम सफलताको ९९ एक-मात्र बाटो हो।', 'जो ९ ९९९ ९९ परिश्रम गर्छ, उही सफल हुन्छ।', 'अब त परिश्रम गर्छौ नि?', 'नगरी कहाँ हुन्छ त!']
# Words after tokenization
# ['परिश्रम', 'नगरी', 'हुन्छ?', 'परिश्रम', 'सफलताको', '९९', 'एक-मात्र', 'बाटो', 'हो।', 'जो', '९', '९९९', '९९', 'परिश्रम', 'गर्छ', 'उही', 'सफल', 'हुन्छ।', 'अब', 'त', 'परिश्रम', 'गर्छौ', 'नि?', 'नगरी', 'कहाँ', 'हुन्छ', 'त!']
# After removing special symbols and numbers
# ['परिश्रम', 'नगरी', 'हुन्छ', 'परिश्रम', 'सफलताको', 'एकमात्र', 'बाटो', 'हो', 'जो', 'परिश्रम', 'गर्छ', 'उही', 'सफल', 'हुन्छ', 'अब', 'त', 'परिश्रम', 'गर्छौ', 'नि', 'नगरी', 'कहाँ', 'हुन्छ', 'त']
# Words after removing stopwords
# ['परिश्रम', 'नगरी', 'परिश्रम', 'सफलताको', 'एकमात्र', 'परिश्रम', 'उही', 'सफल', 'परिश्रम', 'गर्छौ', 'नगरी']
# Sentences
# ['परिश्रम नगरी हुन्छ?', 'परिश्रम सफलताको बाटो हो।', 'जो परिश्रम गर्छ, उही सफल हुन्छ।', 'अब परिश्रम गर्छौ नि?', 'नगरी हुन्छ त!']
# Words after tokenization
# ['परिश्रम', 'नगरी', 'हुन्छ?', 'परिश्रम', 'सफलताको', 'बाटो', 'हो।', 'जो', 'परिश्रम', 'गर्छ', 'उही', 'सफल', 'हुन्छ।', 'अब', 'परिश्रम', 'गर्छौ', 'नि?', 'नगरी', 'हुन्छ', 'त!']
# After removing special symbols and numbers
# ['परिश्रम', 'नगरी', 'हुन्छ', 'परिश्रम', 'सफलताको', 'बाटो', 'हो', 'जो', 'परिश्रम', 'गर्छ', 'उही', 'सफल', 'हुन्छ', 'अब', 'परिश्रम', 'गर्छौ', 'नि', 'नगरी', 'हुन्छ', 'त']
# Words after removing stopwords
# ['परिश्रम', 'नगरी', 'परिश्रम', 'सफलताको', 'परिश्रम', 'उही', 'सफल', 'परिश्रम', 'गर्छौ', 'नगरी']
# ['परिश्रम', 'नगरी', 'परिश्रम', 'सफलताको', 'एकमात्र', 'परिश्रम', 'उही', 'सफल', 'परिश्रम', 'गर्छौ', 'नगरी']
# ['परिश्रम', 'नगरी', 'परिश्रम', 'सफलताको', 'परिश्रम', 'उही', 'सफल', 'परिश्रम', 'गर्छौ', 'नगरी']
# [[0.09090909090909091, 0.15392247095999503, 0.09090909090909091, 0.18181818181818182, 0.36363636363636365, 0.09090909090909091, 0.09090909090909091], [0.1, 0.0, 0.1, 0.2, 0.4, 0.1, 0.1]]
# 0.8571428571428571
# 0.9451442030944225

# %%
eg3='''३० वर्षपछि मुलुकमा राजाको पञ्चायती व्यवस्थाको अवसान र एक पटक फेरि बहुदलीय व्यवस्थाको उदय भएको छ। यस सुखद घडीको पृष्ठभूमिमा नेपाली आमाका सयौं सपुतहरूले प्रजातन्त्रको निम्ति बलिबेदीमा आफ्नो अमूल्य जीवन न्यौछावर गरेका छन्। तपाईँ हाम्रै बीच निरङ्कुश व्यवस्थाको पोल खोल्ने जीवन्त साक्षीहरूको रूपमा यातना शिविरबाट फर्केका कैयौं अपाङ्गहरू अहिले पनि छँदैछन्। यस प्रजातान्त्रिक लडाइँलाई निरन्तरता दिने क्रममा तपाईँ हाम्रै गाउँघरमा कैयन् घरबारहरू राजनीतिक कारणले बेहाल बनाइएका छन्। जनताको अनवरत सङ्घर्ष र खासगरी अघिल्लो वर्ष राजनीतिक विचारधारा, बर्ग, धर्म, पेसा या जात जातिको कुनै भेदभाव नराखी एक ढिको ढिकको भएर नेपाली जनताको जुझारू र निर्णायक सङ्घर्षले ३० वर्षसम्म एकछत्र रजाइँ गर्दै आएको एक दलीय तानाशाही व्यवस्थालाई लत्‌र्याइयो। अथाह कष्ट, असह्य यातना र निर्मम शोषणमाथि बनेको निरङ्कुशताको महल अब रहेन। ३२ वर्षपछि नेपाली जनता बहुदलीय प्रतिस्पर्धात्मक वातावरणमा आम चुनावमा जान पाइ रहेका छन्। यस सुखद अवसरमा प्रजातान्त्रिक जनमञ्च निरङ्कुशता फाल्न र प्रजातन्त्र ल्याउन सहादत हुनुहुने तमाम शहीदहरूमा कृतज्ञता पूर्वक श्रद्धाञ्जली अर्पण गर्दछ। यस विजयमा नेपाली जनताको अजेय पौरख अभिव्यक्त भएको छ। हामी समस्त नेपाली जनतालाई हार्दिक अभिवादन गर्न चाहन्छौं। यस लामो प्रजातान्त्रिक सङ्घर्षमा सहभागी हुनुहुने तमाम योद्धाहरू धन्यवादका पात्र छन्। हाम्रो यो आन्दोलनमा विदेशी मित्रहरूको न्यानो नैतिक समर्थनले आन्दोलनको सफलताको निम्ति थप उर्जाको काम गर्‍यो। हामी हाम्रा समस्त विदेशी मित्रहरूको यस दिशामा भएको भूमिका र योगदानको उच्च मूल्याङ्कन गर्दछौ र यस पवन घडीमा वहाँहरू प्रति आभार प्रकट गर्दछौँ। प्रजातान्त्रिक जनमञ्च नेपालमा अहिलेसम्म बनेका राजनीतिक सङ्गठनमा सबभन्दा कान्छो सङ्गठन हो। गत २०४७ माघ २ गते मात्र विभिन्न क्षेत्रमा कार्यरत राजनीतिक व्यक्तिहरूको आपसी छलफल र विचार विनिमयको स्वाभाविक निष्कर्ष हो- जनमञ्च। राजनीतिक पार्टीको रूपमा विकास नभइसकेको भए पनि यसले यति छिटो अवधिमा नै जति बढी जन अभिरुचि, समर्थन र सहभागिता पाउन सकेको छ, त्यसले जनमञ्चको नवीन धाराको औचित्यलाई थप पुष्टि गरेको छ। ठूलो मूल्य चुकाएर प्राप्त गरेको प्रजातान्त्रिक उपलब्धिलाई सुदृढ तथा प्रवर्द्धन गर्न हिजोभन्दा बढी सतर्क र जिम्मेवारीका साथ लाग्नु सबै नेपालीहरूको परम दायित्व हो। प्रजातन्त्र-अभिव्यक्ति स्वतन्त्रता र सङ्गठन गर्ने अधिकार मात्र होइन। यसले जनताको गुणस्तरमा सुधार ल्याउन सक्नु पर्दछ। हिजोको शासनले विकास श्रीलङ्कामा हामीलाई पुछारमा मात्र छाडेन आम गरिबी, चरम विषमता र व्यापक बेरोजगारी पनि विरासतमा छाडेको छ। अहिले मुलुकको हालत भनेको बेवारिसे वालकको जस्तो लथालिङ्ग छ। त्यसैले अब आर्थिक सामाजिक क्षेत्रमा प्रजातान्त्रिक पुनर्गठन गर्नु हाम्रो चुनौतीपूर्ण कार्य हो। जनताको आर्थिक सामाजिक जीवनमा व्यापक सुधार ल्याएर मात्रै प्रजातन्त्रलाई सुदृढ र दिगो बनाउन सकिन्छ र मात्रै साँचो अर्थमा प्रजातन्त्रलाई "जनताको, जनताद्वारा, जनताको निम्ति सरकार" मा अनुवाद गर्न सकिन्छ। त्यसै पनि हाम्रो गरिबीले हाम्रो राष्ट्रिय स्वाभीमान र अस्मितालाई निर्बल त बनाएको छँदैछ, त्यसमाथि राष्ट्रियता सम्बन्धी समस्याहरू थाती राख्ने र थुपार्ने काम निरन्तर हुँदै आइरहेका छन्। अझ प्रजातन्त्रको नाममा राष्ट्रिय हितलाई किञ्चित् मात्र पनि आँच आउने काम हुन्छ कि भन्ने विषयमा आज राष्ट्रिय जागरुकता अरू आवश्यक बनेको छ। राष्ट्रिय सङ्कल्प र साहसका साथ हामीले विदेशसँगको सम्बन्धलाई पञ्चशीलका सिद्धान्तका आधारमा सुव्यवस्थित गर्नु पर्दछ। हाम्रो भूराजनीतिक अवस्थाले हामीलाई तर्कसङ्गत र लचिलो विदेशनीति अवलम्वन गर्न प्रेरित गरेको छ। तर यसको अर्थ स्वतन्त्र राष्ट्रिय व्यक्तित्व विकासमा आँच पुर्‍याउने या राष्ट्रिय हितलाई कुनै पनि बहानामा सौदाबाजी गर्ने हुनुहुँदैन। हामीबाट खास गरी चीन तथा भारतसँगको सम्बन्धमा सन्तुलित र सतर्क ढङ्गले घनिष्ट रूपमा समान व्यवहार गरिनु पर्दछ। प्रजातन्त्रको विकास प्रकृयामा हामी नितान्त सुषुप्त अवस्थामा छौँ। हामीले हाम्रा देशवासीलाई मानवजातिको अथक सङ्घर्ष र सभ्यताले सिर्जेका तथा परिष्कृत गरिएका आधुनिकतम मानव मूल्य अनुसरण गर्न सक्षम तुल्याउनु पर्दछ। व्यक्तिगत स्वतन्त्रता र सामाजिक उत्तरदायित्वको आदर्शतम सन्तुलन नै मानव सभ्यता र मानव प्रगतिको अन्तरलुप्‍त रहस्य हो भन्ने कुरा अब विवादको विषय रहेन। व्यक्तिगत स्वतन्त्रताको उपयोग गर्दा सामाजिक उत्तरदायित्वको हेक्का राखिनु पर्दछ। हाम्रो भविष्य र हाम्रो विकल्प भनेको राष्‍ट्रवादी प्रजातान्त्रिक विकल्प नै हो। हाम्रा घोषित लक्ष र सो प्रतिको निष्‍ठा र प्रतिवद्धताको गहनाले यथास्थिति का सीमालाई नाघ्दछ। वर्तमान सामाजिक आर्थिक संरचना र संस्थाबाट द्रुततर सामग्रिक विकासको आकाङ्क्षा फलीभूत हुन सक्दैन। प्रजातान्त्रिक ढङ्गले यस क्षेत्रमा विकासलाई गति दिने गरी परिवर्तन ल्याउनु पर्दछ। त्यसैले प्रजातान्त्रिक जनमञ्चले सामाजिक आर्थिक क्रान्तिको बिगुल फुक्दै आमूल परिवर्तन कारी प्रजातान्त्रिक विकल्पको अवधारणा अघि सारेको हो। स्थापित राजनीतिक शक्तिहरूबाट राष्‍ट्रवादी प्रजातान्त्रिक अभिभारा सम्पन्न हुने आशा राख्ने ठाउँ छैन। राजाको शक्तिले मुलुकलाई निरङ्कुशतामा जकडेको मात्र नभएर आर्थिक सामाजिक रूपमा रसातलमा पुर्‍याइ दियो। राजनीतिक नेतृत्व विशेष शक्ति या कुलको निम्ति सार्वकालिक रूपमा सुरक्षित गर्ने विषय होइन। सत्तामा राजनीतिक एकाधिकारको नाम नै तानाशाही या निरङ्कुश तन्त्र हो। जनताको नाममा पार्टी नोकरशाहहरूले या प्रजातन्त्रको नाममा सम्भ्रान्तहरूले शासन गर्ने परिपाटी अभिशापपूर्ण रहेको तथ्य सबैको सामु छर्लङ्ग छ। सत्तामा राजनीतिक नेतृत्व आवधिक रूपमा जनताको अनुमोदन लिई रहनु पर्दछ र प्रतिस्पर्धालाई स्विकार्नु पर्दछ। अर्कोतिर सत्ता लिप्साको निम्ति राष्ट्रिय स्वार्थलाई गौण र सौदाबाजीको विषय बनाउने र राष्ट्रिय हितको जगेर्ना भन्दा पनि पराई मुलुकको हितमा वकालत गर्ने प्रवृत्ति पनि राजनीतिक शक्तिहरूमा छदैछ। नयाँ राजनीतिक नेतृत्वको खाँचो, यसैले परेको हो। प्रजातान्त्रिक जनमञ्च यस दिशामा प्रारंभिक पाइलो हो। हामी सवल प्रजातान्त्रिक विकल्प विकासको निम्ति कृतसङ्कल्पित छौँ। जातीय तथा भौगोलिक बनोटको हिसाबले हाम्रो देश भिन्नताको मेल हो। बिभिन्न जातजाति भाषाभाषी र उनीहरूको आ- आफ्नै परम्परा र संस्कृतिले नेपाललाई "सयौं फूलहरूको फूलबारी" बनाइ दिएको छ। हामी कहाँ धर्म, भाषा, भेष भूषा, चाडबाड, रीतिरिवाज चलन वा परम्पराको भिन्नताले अलग अलग जातीय अस्तित्व बोकेको मात्र नभएर पारस्परिक समझदारी, सदभाव, सहिष्णुता र एकताको आदर्श भावले साझा राष्ट्रिय संस्कृतिको धरोहर खडा गरेको छ। यति हुँदाहुँदै पनि यस क्षेत्रमा समस्याहरू छन्। शासक वर्गका क्रियाकलापबाट विभिन्न जाती, भाषा तथा संस्कृति बीच विभेद भएको छ। सामाजिक विकासका प्रवाहमा कतिपय जातिहरू खास गरी जनजातिहरू पछि परेका छन्। असमान जातीय विकासले सृजेका समस्याहरू सधैं भरि थाती राखेर वा उपेक्षा गरेर राख्न मिल्दैन। जनतामा जातीय भेदभावको बोध विकास हुन थालेपछि त्यसले कस्तो भयावह रूप लिन्छ भन्ने कुरा हामीले छिमेकी मुलुककै विकासक्रमबाट हेरे पनि प्रष्ट हुन्छ। आगामी दिनमा हामीले प्राथमिकताका साथ समाधान गर्नु पर्ने समस्या यो पनि हो। तर सबैले के कुरा बुझ्नु जरुरी छ भने यो समस्या विद्यमान छ भन्ने नाउँमा यसलाई जातीय मेलमिलाप र राष्ट्रिय अखण्डतामा खलल पुग्ने गरी साम्प्रदायिकता भडकाउने या राष्ट्रिय विघटन कार्यमा सघाउ पुर्‍याउने कार्य गर्न कसैलाई अनुमति हुने छैन। हिजोको निरङ्कुश शासनको तर काढेर बसेकाहरू जातीय हितका इसामसिह बन्न खोजेको हरकतलाई खास गरी सम्बन्धित क्षेत्रबाट नै स्यालको निरर्थक धुर्त्याई हो भनेर बुझ्न र बुझाउन जरुरी छ। यसै गरी हाम्रो भौगोलिक बनोटका अतिरिक्त शासक वर्गहरूको असन्तुलित नीति र सीमान्त क्षेत्रको शोषणबाट केन्द्र सिंगार्ने नीतिले गर्दा क्षेत्रीय विकासमा जवर्जस्त असन्तुलन कायम हुन गएको छ। दुर्गम तथा पहाडी क्षेत्र, सुदूर पश्चिम इलाका विकास प्रवाहमा समाहित हुन सकेका छैनन्। सिमान्त क्षेत्रको तराई त्यस्तै जर्जर र उजाड छ। यस असन्तुलनलाई हामीले कहिले सम्म थेग्न सक्छौँ? अब उप्रान्त विकास सम्बन्धी नीति, कार्यक्रम तथा परियोजना तर्जुमा तथा सञ्चालन गर्दा यस असन्तुलनलाई मध्ये नजर राखेर सञ्चालन गरिनु पर्दछ र पिछडिएका क्षेत्रमा प्राथमिकता दिनु पर्दछ। आदरणीय देशवासीहरू ! आमा निर्वाचनको दिन नजिकिंदै छ। कम्तीमा राष्ट्रलाई आगामी पाँच वर्षका निम्ति दिशा दिने काम यस निर्वाचनबाट गठित संसद र सरकारले गर्ने छ। संसद र सरकारको बनोटलाई विद्यमान पार्टी र उनीहरूको प्रत्यासीहरूले प्रभावित गर्ने भएको हुँदा उनीहरूप्रति मोटामोटी रूपमा विचार बनाउनु जरुरी छ। अहिले मूलतः यस निर्वाचनमा निम्न राजनीतिक शक्तिहरू क्रियाशील रहेका छन्। 
१ राजाको पञ्चायती शक्ति- बहुदलीय व्यवस्था पुनर्स्थापनको लगत्तै पछि एकै दिन एउटै झण्डा बोकि एउटै नाममा खुलेका दुईवटा राष्ट्रिय प्रजातन्त्र पार्टी राजा र राजदरबारकै जुम्ल्याहा बच्चा हुन् भन्नुमा अत्युक्ति नहोला। पञ्चायतको परिवर्तित रूपलाई यिनीहरूले प्रतिनिधित्व गर्दछन्। यिनीहरूले विगत ३० वर्षमा कयौं पटक राजाको सकृय नेतृत्वको कसम खाएका छन्। राजा पनि त्यसैगरी नाचेका छन्। निर्दलीयताको नाममा निर्मन दमनबाट चलेको तानाशाही शासन नै उनीहरूको पुर्ख्यौली राजनीतिक सम्पत्ति हो। शोषण विहिन् समाज निर्माण गर्ने नाममा उनीहरूले राष्ट्रको सर्वस्व लुटेका छन् र अथाह सम्पाति विदेशमा थुपारेका छन्। ३० वर्षको उनीहरूको कुकर्मलाई हेरेर इतिहासले जुन निर्णय दिएको छ त्यसलाई राज्यसत्ता र ब्रह्मलुटको सम्पत्तिले उल्ट्‍याउन उनीहरू भरमग्दुर लागेका छन्। इतिहासको पाङ्ग्रालाई पछि धकेल्ने उनीहरूका दुश्‍चेष्‍टा किमार्थ सफल हुने छैनन्। अन्तरिम मन्त्रिमण्डलले जनादेशको शाहसपूर्वक कार्यान्वयन गर्न नसकेर पनि उनीहरू अहिले छाती खोल्न पाइरहेका छन्। इतिहासको निर्णयलाई बदर गराउन खोज्ने यस शक्तिलाई आगामी निर्वाचनले पनि यसरी ङ्याक्नु पर्दछ जसले गर्दा पुनः अर्को तानाशाही शक्ति शिर उठाउने हिम्मत गर्न नसकोस्। 
२. नेपाली काँग्रेस- राजाको निरङ्कुशताको रूपमा रहेको पञ्चायती व्यवस्थालाई मास्न र बहुदलीय व्यवस्थाको स्थापनाको निम्ति नेपाली काङ्ग्रेसले गरेको योगदान सराहनीय छ। पञ्चायत विरोधी आन्दोलनकारी शक्तिहरूसँगको संयुक्त आन्दोलनको विरोध र खासगरी ३० को दशकमा आएर निरङ्कुश राजतन्त्रसँगको मेलमिलापको नीतिले गर्दा नै पञ्चायतको आयु यतिसम्म लामो हुन गएको हो। गएको जन आन्दोलनमा आन्दोलनको उद्‍घोष मात्र होइन तालमेल कै हदसम्म भए पनि संयुक्त आन्दोलनमा आउने उसको निर्णय प्रजातान्त्रिक आन्दोलनको विकासको निम्ति निर्णायक मोड बन्न पुग्यो। आन्दोलनको सफलता पछि कम्युनिष्ट तथा राजाको शक्तिलाई साथमा लिएर सत्ता सम्हाले पछि चरित्रगत कारणले नै यसले राजाको निरङ्कुशतामा हुर्केका राजनीतिक तथा आर्थिक अपराधीहरूलाई कार्यवाही गर्नमा उदासीनता मात्र देखाएन जघन्य अपराधीहरूलाई समेत छोड्ने हास्यास्पद काम समेत गर्न सङ्कोच मानेन। अहिले पार्टीभित्र राष्ट्रियता तथा प्रजातन्त्र विरोधी शक्तिले प्रश्रय पाइरहेका छन्। यही कारण हिजोका वरिष्ठ पञ्चहरूले समेत यसमा प्रवेश पाएका हुन्। प्रबल पार्टी ब्युरोक्रेसी र आन्तरिक प्रजातन्त्रको अभावको बारेमा पार्टीका स्वयम् कार्यकर्ताहरू आवाज उठाइरहेका छन्। "चीनसँग मित्रता र भारतसँग घनिष्‍टता" को यसको घोषित नीतिको दुष्परिणामहरू प्रकट हुन थालेका छन्।१९५० र १९६५ को सन्धिको अन्यायपूर्ण प्रावधानले राष्ट्रिय स्वार्थ र स्वाभीमानलाई किचिरहेको छ। त्यस माथि अरू बोझहरू थपिँदै छन्। कोशी र गण्डकी सम्झौतामा लागेको राष्ट्रिय कलङ्क र ठगिएको घाउ आलै छ। भारत आफ्नो प्रतिरक्षा अवधारणा मनाउन दवाब दिइरहेको छ। भारतीय एकाधिकार पूँजीको जकडबाट नेपाली अर्थतन्त्र आक्रान्त छ। स्वतन्त्र राष्ट्रिय अर्थतन्त्रको विकासमा खुला सीमाना एउटा तगारो हो। सीमाना नियन्त्रण गर्ने राष्ट्रिय जागरण बढी रहेको छ। यो बेला साझा नदी, साझा मुद्रा र कुनै कुनै कुनाबाट साझा सरकारको समेत कुरा उठ्नुले मुलुकको राष्‍ट्रवादी शक्ति चिन्तित र ससङ्कित हुनु र सजगता देखाउनु स्वाभाविक हो। वर्तमान संविधानमा महत्वपूर्ण सन्धि सम्झौता गरिँदा सदनको दुई तिहाइ बहुमतको अनुमोदन चाहिने प्रावधान छ। यसको ध्येय राष्ट्रिय हितका विषयमा निर्णय लिइँदा राष्ट्रिय सहमति खोज्ने नै हो। राष्ट्रिय हितलाई कुनै पार्टी विशेषको सेन्टिमेन्टले डिक्टेट गरिनु हुँदैन। नेपाली काँग्रेसमा वर्तमान सामाजिक, आर्थिक संरचनालाई विकास र जनताको पक्षमा आमूल परिवर्तन गराउने सङ्कल्प शक्तिको सर्वथा अभाव छ। यथास्थितिलाई कायम राखेर ल्याइने प्रजातान्त्रिक समाजवादको रूप के होला? समाजको विपन्न र असक्त वर्गले नयाँ परिवर्तनलाई कसरी अनुभव गर्ने? नेपाली काँग्रेसले पूर्ववर्ती शासनका आर्थिक सामाजिक नीतिहरूलाई विरासतमा लिने र उनीहरूकै पदचिह्नमा हिँड्ने सङ्केत गरी सकेको छ। 
३. कम्युनिष्ट शक्ति- नेपालको वर्तमान शक्ति समीकरणमा अर्को महत्वपूर्ण शक्ति कम्युनिष्ट शक्ति हो। राष्ट्रियताका सवालमा र प्रजातन्त्र स्थापनाको सङ्घर्षमा यसको योगदान सकारात्मक रहेको तथ्यलाई कसैले इन्कार्न मिल्दैन। यसैकारण नै विश्व कम्युनिष्ट आन्दोलन सङ्कटबाट गुज्रिरहेको भए पनि यहाँ कम्युनिष्ट आन्दोलन प्रबल रूपमा रहेको छ। यति हुँदाहुँदै पनि यो आन्दोलन एकीकृत आन्दोलन होइन। विभिन्न धारा र चिरामा विभक्त यो आन्दोलनको विभाजन जनता र राष्ट्रका प्रश्‍नमा भन्दा पनि नेतृत्व तृष्णा, विदेशी नक्कल र जडसूत्रको अनुसरणमा भएको छ। बेला बखत यो आन्दोलन उग्र बामपन्थ र दक्षिणपन्थको सिकार रहेको कुरा स्वयम् कम्युनिष्टहरू स्विकार्दछन्। यतिमात्र होइन उनीहरू अहिले पनि एक अर्कालाई दक्षिणपन्थी र जडसूत्रवादीको आरोप प्रत्यारोप लगाइ रहेका छन्। सामाजिक अन्याय र शोषणको विरुद्धमा आवाज उठाउने काम त यस आन्दोलनबाट भएको छ तर तर्कसङ्गत सामाजिक न्याय र समुन्नति कसरी स्थापित गर्ने बारेमा नेपाली कम्युनिष्टहरूले कुनै भरपर्दो कार्यक्रम दिन सकेका छैनन्। नेपाली कम्युनिष्ट आन्दोलन बृहत्तर प्रजातान्त्रिक आन्दोलनको एक हिस्सा भएर पनि यसले नेपालको भूराजनीतिक यथार्थको नेतृत्व गर्न सक्दैन। कठोर पार्टी ब्युरोक्रेसी, आन्तरिक जनवादको अभाव र अनवरत पार्टीसत्ता सङ्घर्ष यस आन्दोलनका भित्री विशेषताहरू हुन्। खुल्ला समाज र बहुदलीय प्रतिस्पर्धात्मक राजनीतिलाई ठाडै या घुमाउरो पाराले अस्वीकार गर्ने र सत्तामा कम्युनिष्ट नेतृत्व एकाधिकारको वकालत गर्ने धारा अहिले पनि यस आन्दोलनभित्र छँदैछ। राष्‍ट्र र जनतासँग जिम्मेवार भएर प्रभावकारी र तर्क सङ्गत राष्ट्रिय दिशा निर्क्यौल गर्नमा भन्दा पनि यो आन्दोलन "वाल रोग" को बढी सिकार छ। यस आमनिर्वाचनको सिलसिलामा "एक बाम एक ठाम" को प्रस्तावलाई कम्युनिष्टहरू बाटै धुजा धुजा पारियो। उनीहरूको सत्ता लिप्सा, अपरिपक्वता, अहम्, र गैह्र जिम्मेवारीलाई नाप्ने यो भन्दा अरू कुनै मापदण्ड चाहिन्छ र? नेपाली इतिहासमा पहिलो पटक कम्युनिष्टहरू यसपाली सत्तामा अंशियार बन्न पुगेका हुन्। अन्तरिम मन्त्रि मण्डलका सफलता र असफलता नै उनीहरूको पनि वासलात हो। उनीहरू सत्तामा रहेको जनताले राष्ट्रिय जीवनको कुन पक्षमा अनुभव गर्न पाए त्यसको इतिहासले मूल्याङ्कन गर्ने नै छ। हामी यति भन्न विवश छौँ सत्तामा रहेकाहरूले आफ्नो छविलाई विवादास्पद बनाउनबाट जोगाउन सकेनन्। 
४. जातीय तथा साम्प्रदायिक शक्तिहरू जन आन्दोलन पछि नै प्रकट रूपमा जातीय तथा साम्प्रदायिक आधारमा सङ्गठित हुने प्रक्रिया पनि हामी कहाँ देखिएको छ। जातीय अर्थात् साम्प्रदायिक समस्या विद्यमान छ भन्नु, त्यसको उपयुक्त समाधानको खोजी गर्नु र आफ्नो हित तथा उत्थानको निम्ति सङ्गठित प्रयास गर्नु राम्रो कुरा हो। तर पिछडिएका जातिको उत्थानको नाममा वा जातीय अन्तर विरोध नै प्रधान अन्तर विरोध हो भन्ने नाममा जाती जाती बीचको जातीय तथा साम्प्रदायिक सद्‌भावलाई बिथोल्ने गरी या जातीय साम्प्रदायिक दङ्गा भड्काउने क्रियाकलाप कसैबाट पनि हुनुहुँदैन। जातीय तथा साम्प्रदायिक समस्या समाधानको निम्ति केही क्षेत्रबाट सङ्घीय राज्य, स्वायत्त क्षेत्र, पछि परेका जात तथा जनजातिहरूको निम्ति आरक्षण तथा जातीय समानुपातिक प्रतिनिधित्व जस्ता कुरा पनि अघि सारिएका छन्। जातीय भेदभाव र पछौटेपनको समाधान प्रजातान्त्रिक प्रक्रियाबाट नै गरिनु पर्दछ र यसको निम्ति हाम्रो यथार्थभित्र राष्ट्रिय छलफल गर्नु र राष्ट्रिय सहमति निकाल्नु आवश्यक छ जातीय समस्या प्रतिगामी तथा विदेशी शक्ति घुस्ने सबभन्दा सरल राजमार्ग हो भन्ने कुरा सम्बन्धित सबै क्षेत्रले बुझ्नु अनिवार्य छ र त्यसलाई बेलैमा निराकरण गर्ने तर्फ पाइला चाल्नु पर्दछ। 
'''

tokens3=preprocess(eg3)
# Out:
# Sentences
# ['३० वर्षपछि मुलुकमा राजाको पञ्चायती व्यवस्थाको अवसान र एक पटक फेरि बहुदलीय व्यवस्थाको उदय भएको छ।', 'यस सुखद घडीको पृष्ठभूमिमा नेपाली आमाका सयौं सपुतहरूले प्रजातन्त्रको निम्ति बलिबेदीमा आफ्नो अमूल्य जीवन न्यौछावर गरेका छन्।', 'तपाईँ हाम्रै बीच निरङ्कुश व्यवस्थाको पोल खोल्ने जीवन्त साक्षीहरूको रूपमा यातना शिविरबाट फर्केका कैयौं अपाङ्गहरू अहिले पनि छँदैछन्।', 'यस प्रजातान्त्रिक लडाइँलाई निरन्तरता दिने क्रममा तपाईँ हाम्रै गाउँघरमा कैयन् घरबारहरू राजनीतिक कारणले बेहाल बनाइएका छन्।', 'जनताको अनवरत सङ्घर्ष र खासगरी अघिल्लो वर्ष राजनीतिक विचारधारा, बर्ग, धर्म, पेसा या जात जातिको कुनै भेदभाव नराखी एक ढिको ढिकको भएर नेपाली जनताको जुझारू र निर्णायक सङ्घर्षले ३० वर्षसम्म एकछत्र रजाइँ गर्दै आएको एक दलीय तानाशाही व्यवस्थालाई लत्\u200cर्याइयो।', 'अथाह कष्ट, असह्य यातना र निर्मम शोषणमाथि बनेको निरङ्कुशताको महल अब रहेन।', '३२ वर्षपछि नेपाली जनता बहुदलीय प्रतिस्पर्धात्मक वातावरणमा आम चुनावमा जान पाइ रहेका छन्।', 'यस सुखद अवसरमा प्रजातान्त्रिक जनमञ्च निरङ्कुशता फाल्न र प्रजातन्त्र ल्याउन सहादत हुनुहुने तमाम शहीदहरूमा कृतज्ञता पूर्वक श्रद्धाञ्जली अर्पण गर्दछ।', 'यस विजयमा नेपाली जनताको अजेय पौरख अभिव्यक्त भएको छ।', 'हामी समस्त नेपाली जनतालाई हार्दिक अभिवादन गर्न चाहन्छौं।', 'यस लामो प्रजातान्त्रिक सङ्घर्षमा सहभागी हुनुहुने तमाम योद्धाहरू धन्यवादका पात्र छन्।', 'हाम्रो यो आन्दोलनमा विदेशी मित्रहरूको न्यानो नैतिक समर्थनले आन्दोलनको सफलताको निम्ति थप उर्जाको काम गर्\u200dयो।', 'हामी हाम्रा समस्त विदेशी मित्रहरूको यस दिशामा भएको भूमिका र योगदानको उच्च मूल्याङ्कन गर्दछौ र यस पवन घडीमा वहाँहरू प्रति आभार प्रकट गर्दछौँ।', 'प्रजातान्त्रिक जनमञ्च नेपालमा अहिलेसम्म बनेका राजनीतिक सङ्गठनमा सबभन्दा कान्छो सङ्गठन हो।', 'गत २०४७ माघ २ गते मात्र विभिन्न क्षेत्रमा कार्यरत राजनीतिक व्यक्तिहरूको आपसी छलफल र विचार विनिमयको स्वाभाविक निष्कर्ष हो- जनमञ्च।', 'राजनीतिक पार्टीको रूपमा विकास नभइसकेको भए पनि यसले यति छिटो अवधिमा नै जति बढी जन अभिरुचि, समर्थन र सहभागिता पाउन सकेको छ, त्यसले जनमञ्चको नवीन धाराको औचित्यलाई थप पुष्टि गरेको छ।', 'ठूलो मूल्य चुकाएर प्राप्त गरेको प्रजातान्त्रिक उपलब्धिलाई सुदृढ तथा प्रवर्द्धन गर्न हिजोभन्दा बढी सतर्क र जिम्मेवारीका साथ लाग्नु सबै नेपालीहरूको परम दायित्व हो।', 'प्रजातन्त्र-अभिव्यक्ति स्वतन्त्रता र सङ्गठन गर्ने अधिकार मात्र होइन।', 'यसले जनताको गुणस्तरमा सुधार ल्याउन सक्नु पर्दछ।', 'हिजोको शासनले विकास श्रीलङ्कामा हामीलाई पुछारमा मात्र छाडेन आम गरिबी, चरम विषमता र व्यापक बेरोजगारी पनि विरासतमा छाडेको छ।', 'अहिले मुलुकको हालत भनेको बेवारिसे वालकको जस्तो लथालिङ्ग छ।', 'त्यसैले अब आर्थिक सामाजिक क्षेत्रमा प्रजातान्त्रिक पुनर्गठन गर्नु हाम्रो चुनौतीपूर्ण कार्य हो।', 'जनताको आर्थिक सामाजिक जीवनमा व्यापक सुधार ल्याएर मात्रै प्रजातन्त्रलाई सुदृढ र दिगो बनाउन सकिन्छ र मात्रै साँचो अर्थमा प्रजातन्त्रलाई "जनताको, जनताद्वारा, जनताको निम्ति सरकार" मा अनुवाद गर्न सकिन्छ।', 'त्यसै पनि हाम्रो गरिबीले हाम्रो राष्ट्रिय स्वाभीमान र अस्मितालाई निर्बल त बनाएको छँदैछ, त्यसमाथि राष्ट्रियता सम्बन्धी समस्याहरू थाती राख्ने र थुपार्ने काम निरन्तर हुँदै आइरहेका छन्।', 'अझ प्रजातन्त्रको नाममा राष्ट्रिय हितलाई किञ्चित् मात्र पनि आँच आउने काम हुन्छ कि भन्ने विषयमा आज राष्ट्रिय जागरुकता अरू आवश्यक बनेको छ।', 'राष्ट्रिय सङ्कल्प र साहसका साथ हामीले विदेशसँगको सम्बन्धलाई पञ्चशीलका सिद्धान्तका आधारमा सुव्यवस्थित गर्नु पर्दछ।', 'हाम्रो भूराजनीतिक अवस्थाले हामीलाई तर्कसङ्गत र लचिलो विदेशनीति अवलम्वन गर्न प्रेरित गरेको छ।', 'तर यसको अर्थ स्वतन्त्र राष्ट्रिय व्यक्तित्व विकासमा आँच पुर्\u200dयाउने या राष्ट्रिय हितलाई कुनै पनि बहानामा सौदाबाजी गर्ने हुनुहुँदैन।', 'हामीबाट खास गरी चीन तथा भारतसँगको सम्बन्धमा सन्तुलित र सतर्क ढङ्गले घनिष्ट रूपमा समान व्यवहार गरिनु पर्दछ।', 'प्रजातन्त्रको विकास प्रकृयामा हामी नितान्त सुषुप्त अवस्थामा छौँ।', 'हामीले हाम्रा देशवासीलाई मानवजातिको अथक सङ्घर्ष र सभ्यताले सिर्जेका तथा परिष्कृत गरिएका आधुनिकतम मानव मूल्य अनुसरण गर्न सक्षम तुल्याउनु पर्दछ।', 'व्यक्तिगत स्वतन्त्रता र सामाजिक उत्तरदायित्वको आदर्शतम सन्तुलन नै मानव सभ्यता र मानव प्रगतिको अन्तरलुप्\u200dत रहस्य हो भन्ने कुरा अब विवादको विषय रहेन।', 'व्यक्तिगत स्वतन्त्रताको उपयोग गर्दा सामाजिक उत्तरदायित्वको हेक्का राखिनु पर्दछ।', 'हाम्रो भविष्य र हाम्रो विकल्प भनेको राष्\u200dट्रवादी ...
# Words after tokenization
# ['३०', 'वर्षपछि', 'मुलुकमा', 'राजाको', 'पञ्चायती', 'व्यवस्थाको', 'अवसान', 'र', 'एक', 'पटक', 'फेरि', 'बहुदलीय', 'व्यवस्थाको', 'उदय', 'भएको', 'छ।', 'यस', 'सुखद', 'घडीको', 'पृष्ठभूमिमा', 'नेपाली', 'आमाका', 'सयौं', 'सपुतहरूले', 'प्रजातन्त्रको', 'निम्ति', 'बलिबेदीमा', 'आफ्नो', 'अमूल्य', 'जीवन', 'न्यौछावर', 'गरेका', 'छन्।', 'तपाईँ', 'हाम्रै', 'बीच', 'निरङ्कुश', 'व्यवस्थाको', 'पोल', 'खोल्ने', 'जीवन्त', 'साक्षीहरूको', 'रूपमा', 'यातना', 'शिविरबाट', 'फर्केका', 'कैयौं', 'अपाङ्गहरू', 'अहिले', 'पनि', 'छँदैछन्।', 'यस', 'प्रजातान्त्रिक', 'लडाइँलाई', 'निरन्तरता', 'दिने', 'क्रममा', 'तपाईँ', 'हाम्रै', 'गाउँघरमा', 'कैयन्', 'घरबारहरू', 'राजनीतिक', 'कारणले', 'बेहाल', 'बनाइएका', 'छन्।', 'जनताको', 'अनवरत', 'सङ्घर्ष', 'र', 'खासगरी', 'अघिल्लो', 'वर्ष', 'राजनीतिक', 'विचारधारा', 'बर्ग', 'धर्म', 'पेसा', 'या', 'जात', 'जातिको', 'कुनै', 'भेदभाव', 'नराखी', 'एक', 'ढिको', 'ढिकको', 'भएर', 'नेपाली', 'जनताको', 'जुझारू', 'र', 'निर्णायक', 'सङ्घर्षले', '३०', 'वर्षसम्म', 'एकछत्र', 'रजाइँ', 'गर्दै', 'आएको', 'एक', 'दलीय', 'तानाशाही', 'व्यवस्थालाई', 'लत्\u200cर्याइयो।', 'अथाह', 'कष्ट', 'असह्य', 'यातना', 'र', 'निर्मम', 'शोषणमाथि', 'बनेको', 'निरङ्कुशताको', 'महल', 'अब', 'रहेन।', '३२', 'वर्षपछि', 'नेपाली', 'जनता', 'बहुदलीय', 'प्रतिस्पर्धात्मक', 'वातावरणमा', 'आम', 'चुनावमा', 'जान', 'पाइ', 'रहेका', 'छन्।', 'यस', 'सुखद', 'अवसरमा', 'प्रजातान्त्रिक', 'जनमञ्च', 'निरङ्कुशता', 'फाल्न', 'र', 'प्रजातन्त्र', 'ल्याउन', 'सहादत', 'हुनुहुने', 'तमाम', 'शहीदहरूमा', 'कृतज्ञता', 'पूर्वक', 'श्रद्धाञ्जली', 'अर्पण', 'गर्दछ।', 'यस', 'विजयमा', 'नेपाली', 'जनताको', 'अजेय', 'पौरख', 'अभिव्यक्त', 'भएको', 'छ।', 'हामी', 'समस्त', 'नेपाली', 'जनतालाई', 'हार्दिक', 'अभिवादन', 'गर्न', 'चाहन्छौं।', 'यस', 'लामो', 'प्रजातान्त्रिक', 'सङ्घर्षमा', 'सहभागी', 'हुनुहुने', 'तमाम', 'योद्धाहरू', 'धन्यवादका', 'पात्र', 'छन्।', 'हाम्रो', 'यो', 'आन्दोलनमा', 'विदेशी', 'मित्रहरूको', 'न्यानो', 'नैतिक', 'समर्थनले', 'आन्दोलनको', 'सफलताको', 'निम्ति', 'थप', 'उर्जाको', 'काम', 'गर्\u200dयो।', 'हामी', 'हाम्रा', 'समस्त', 'विदेशी', 'मित्रहरूको', 'यस', 'दिशामा', 'भएको', 'भूमिका', 'र', 'योगदानको', 'उच्च', 'मूल्याङ्कन', 'गर्दछौ', 'र', 'यस', 'पवन', 'घडीमा', 'वहाँहरू', 'प्रति', 'आभार', 'प्रकट', 'गर्दछौँ।', 'प्रजातान्त्रिक', 'जनमञ्च', 'नेपालमा', 'अहिलेसम्म', 'बनेका', 'राजनीतिक', 'सङ्गठनमा', 'सबभन्दा', 'कान्छो', 'सङ्गठन', 'हो।', 'गत', '२०४७', 'माघ', '२', 'गते', 'मात्र', 'विभिन्न', 'क्षेत्रमा', 'कार्यरत', 'राजनीतिक', 'व्यक्तिहरूको', 'आपसी', 'छलफल', 'र', 'विचार', 'विनिमयको', 'स्वाभाविक', 'निष्कर्ष', 'हो-', 'जनमञ्च।', 'राजनीतिक', 'पार्टीको', 'रूपमा', 'विकास', 'नभइसकेको', 'भए', 'पनि', 'यसले', 'यति', 'छिटो', 'अवधिमा', 'नै', 'जति', 'बढी', 'जन', 'अभिरुचि', 'समर्थन', 'र', 'सहभागिता', 'पाउन', 'सकेको', 'छ', 'त्यसले', 'जनमञ्चको', 'नवीन', 'धाराको', 'औचित्यलाई', 'थप', 'पुष्टि', 'गरेको', 'छ।', 'ठूलो', 'मूल्य', 'चुकाएर', 'प्राप्त', 'गरेको', 'प्रजातान्त्रिक', 'उपलब्धिलाई', 'सुदृढ', 'तथा', 'प्रवर्द्धन', 'गर्न', 'हिजोभन्दा', 'बढी', 'सतर्क', 'र', 'जिम्मेवारीका', 'साथ', 'लाग्नु', 'सबै', 'नेपालीहरूको', 'परम', 'दायित्व', 'हो।', 'प्रजातन्त्र-अभिव्यक्ति', 'स्वतन्त्रता', 'र', 'सङ्गठन', 'गर्ने', 'अधिकार', 'मात्र', 'होइन।', 'यसले', 'जनताको', 'गुणस्तरमा', 'सुधार', 'ल्याउन', 'सक्नु', 'पर्दछ।', 'हिजोको', 'शासनले', 'विकास', 'श्रीलङ्कामा', 'हामीलाई', 'पुछारमा', 'मात्र', 'छाडेन', 'आम', 'गरिबी', 'चरम', 'विषमता', 'र', 'व्यापक', 'बेरोजगारी', 'पनि', 'विरासतमा', 'छाडेको', 'छ।', 'अहिले', 'मुलुकको', 'हालत', 'भनेको', 'बेवारिसे', 'वालकको', 'जस्तो', 'लथालिङ्ग', 'छ।', 'त्यसैले', 'अब', 'आर्थिक', 'सामाजिक', 'क्षेत्रमा', 'प्रजातान्त्रिक', 'पुनर्गठन', 'गर्नु', 'हाम्रो', 'चुनौतीपूर्ण', 'कार्य', 'हो।', 'जनताको', 'आर्थिक', 'सामाजिक', 'जीवनमा', 'व्यापक', 'सुधार', 'ल्याएर', 'मात्रै', 'प्रजातन्त्रलाई', 'सुदृढ', 'र', 'दिगो', 'बनाउन', 'सकिन्छ', 'र', 'मात्रै', 'साँचो', 'अर्थमा', 'प्रजातन्त्रलाई', '"जनताको', 'जनताद्वारा', 'जनताको', 'निम्ति', 'सरकार"', 'मा', 'अनुवाद', 'गर्न', 'सकिन्छ।', 'त्यसै', 'पनि', 'हाम्रो', 'गरिबीले', 'हाम्रो', 'राष्ट्रिय', 'स्वाभीमान', 'र', 'अस्मितालाई', 'निर्बल', 'त', 'बनाएको', 'छँदैछ', 'त्यसमाथि', 'राष्ट्रियता', 'सम्बन्धी', 'समस्याहरू', 'थाती', 'राख्ने', 'र', 'थुपार्ने', 'काम', ...
# After removing special symbols and numbers
# ['वर्षपछि', 'मुलुकमा', 'राजाको', 'पञ्चायती', 'व्यवस्थाको', 'अवसान', 'र', 'एक', 'पटक', 'फेरि', 'बहुदलीय', 'व्यवस्थाको', 'उदय', 'भएको', 'छ', 'यस', 'सुखद', 'घडीको', 'पृष्ठभूमिमा', 'नेपाली', 'आमाका', 'सयौं', 'सपुतहरूले', 'प्रजातन्त्रको', 'निम्ति', 'बलिबेदीमा', 'आफ्नो', 'अमूल्य', 'जीवन', 'न्यौछावर', 'गरेका', 'छन्', 'तपाईँ', 'हाम्रै', 'बीच', 'निरङ्कुश', 'व्यवस्थाको', 'पोल', 'खोल्ने', 'जीवन्त', 'साक्षीहरूको', 'रूपमा', 'यातना', 'शिविरबाट', 'फर्केका', 'कैयौं', 'अपाङ्गहरू', 'अहिले', 'पनि', 'छँदैछन्', 'यस', 'प्रजातान्त्रिक', 'लडाइँलाई', 'निरन्तरता', 'दिने', 'क्रममा', 'तपाईँ', 'हाम्रै', 'गाउँघरमा', 'कैयन्', 'घरबारहरू', 'राजनीतिक', 'कारणले', 'बेहाल', 'बनाइएका', 'छन्', 'जनताको', 'अनवरत', 'सङ्घर्ष', 'र', 'खासगरी', 'अघिल्लो', 'वर्ष', 'राजनीतिक', 'विचारधारा', 'बर्ग', 'धर्म', 'पेसा', 'या', 'जात', 'जातिको', 'कुनै', 'भेदभाव', 'नराखी', 'एक', 'ढिको', 'ढिकको', 'भएर', 'नेपाली', 'जनताको', 'जुझारू', 'र', 'निर्णायक', 'सङ्घर्षले', 'वर्षसम्म', 'एकछत्र', 'रजाइँ', 'गर्दै', 'आएको', 'एक', 'दलीय', 'तानाशाही', 'व्यवस्थालाई', 'लत्\u200cर्याइयो', 'अथाह', 'कष्ट', 'असह्य', 'यातना', 'र', 'निर्मम', 'शोषणमाथि', 'बनेको', 'निरङ्कुशताको', 'महल', 'अब', 'रहेन', 'वर्षपछि', 'नेपाली', 'जनता', 'बहुदलीय', 'प्रतिस्पर्धात्मक', 'वातावरणमा', 'आम', 'चुनावमा', 'जान', 'पाइ', 'रहेका', 'छन्', 'यस', 'सुखद', 'अवसरमा', 'प्रजातान्त्रिक', 'जनमञ्च', 'निरङ्कुशता', 'फाल्न', 'र', 'प्रजातन्त्र', 'ल्याउन', 'सहादत', 'हुनुहुने', 'तमाम', 'शहीदहरूमा', 'कृतज्ञता', 'पूर्वक', 'श्रद्धाञ्जली', 'अर्पण', 'गर्दछ', 'यस', 'विजयमा', 'नेपाली', 'जनताको', 'अजेय', 'पौरख', 'अभिव्यक्त', 'भएको', 'छ', 'हामी', 'समस्त', 'नेपाली', 'जनतालाई', 'हार्दिक', 'अभिवादन', 'गर्न', 'चाहन्छौं', 'यस', 'लामो', 'प्रजातान्त्रिक', 'सङ्घर्षमा', 'सहभागी', 'हुनुहुने', 'तमाम', 'योद्धाहरू', 'धन्यवादका', 'पात्र', 'छन्', 'हाम्रो', 'यो', 'आन्दोलनमा', 'विदेशी', 'मित्रहरूको', 'न्यानो', 'नैतिक', 'समर्थनले', 'आन्दोलनको', 'सफलताको', 'निम्ति', 'थप', 'उर्जाको', 'काम', 'गर्\u200dयो', 'हामी', 'हाम्रा', 'समस्त', 'विदेशी', 'मित्रहरूको', 'यस', 'दिशामा', 'भएको', 'भूमिका', 'र', 'योगदानको', 'उच्च', 'मूल्याङ्कन', 'गर्दछौ', 'र', 'यस', 'पवन', 'घडीमा', 'वहाँहरू', 'प्रति', 'आभार', 'प्रकट', 'गर्दछौँ', 'प्रजातान्त्रिक', 'जनमञ्च', 'नेपालमा', 'अहिलेसम्म', 'बनेका', 'राजनीतिक', 'सङ्गठनमा', 'सबभन्दा', 'कान्छो', 'सङ्गठन', 'हो', 'गत', 'माघ', 'गते', 'मात्र', 'विभिन्न', 'क्षेत्रमा', 'कार्यरत', 'राजनीतिक', 'व्यक्तिहरूको', 'आपसी', 'छलफल', 'र', 'विचार', 'विनिमयको', 'स्वाभाविक', 'निष्कर्ष', 'हो', 'जनमञ्च', 'राजनीतिक', 'पार्टीको', 'रूपमा', 'विकास', 'नभइसकेको', 'भए', 'पनि', 'यसले', 'यति', 'छिटो', 'अवधिमा', 'नै', 'जति', 'बढी', 'जन', 'अभिरुचि', 'समर्थन', 'र', 'सहभागिता', 'पाउन', 'सकेको', 'छ', 'त्यसले', 'जनमञ्चको', 'नवीन', 'धाराको', 'औचित्यलाई', 'थप', 'पुष्टि', 'गरेको', 'छ', 'ठूलो', 'मूल्य', 'चुकाएर', 'प्राप्त', 'गरेको', 'प्रजातान्त्रिक', 'उपलब्धिलाई', 'सुदृढ', 'तथा', 'प्रवर्द्धन', 'गर्न', 'हिजोभन्दा', 'बढी', 'सतर्क', 'र', 'जिम्मेवारीका', 'साथ', 'लाग्नु', 'सबै', 'नेपालीहरूको', 'परम', 'दायित्व', 'हो', 'प्रजातन्त्रअभिव्यक्ति', 'स्वतन्त्रता', 'र', 'सङ्गठन', 'गर्ने', 'अधिकार', 'मात्र', 'होइन', 'यसले', 'जनताको', 'गुणस्तरमा', 'सुधार', 'ल्याउन', 'सक्नु', 'पर्दछ', 'हिजोको', 'शासनले', 'विकास', 'श्रीलङ्कामा', 'हामीलाई', 'पुछारमा', 'मात्र', 'छाडेन', 'आम', 'गरिबी', 'चरम', 'विषमता', 'र', 'व्यापक', 'बेरोजगारी', 'पनि', 'विरासतमा', 'छाडेको', 'छ', 'अहिले', 'मुलुकको', 'हालत', 'भनेको', 'बेवारिसे', 'वालकको', 'जस्तो', 'लथालिङ्ग', 'छ', 'त्यसैले', 'अब', 'आर्थिक', 'सामाजिक', 'क्षेत्रमा', 'प्रजातान्त्रिक', 'पुनर्गठन', 'गर्नु', 'हाम्रो', 'चुनौतीपूर्ण', 'कार्य', 'हो', 'जनताको', 'आर्थिक', 'सामाजिक', 'जीवनमा', 'व्यापक', 'सुधार', 'ल्याएर', 'मात्रै', 'प्रजातन्त्रलाई', 'सुदृढ', 'र', 'दिगो', 'बनाउन', 'सकिन्छ', 'र', 'मात्रै', 'साँचो', 'अर्थमा', 'प्रजातन्त्रलाई', '"जनताको', 'जनताद्वारा', 'जनताको', 'निम्ति', 'सरकार"', 'मा', 'अनुवाद', 'गर्न', 'सकिन्छ', 'त्यसै', 'पनि', 'हाम्रो', 'गरिबीले', 'हाम्रो', 'राष्ट्रिय', 'स्वाभीमान', 'र', 'अस्मितालाई', 'निर्बल', 'त', 'बनाएको', 'छँदैछ', 'त्यसमाथि', 'राष्ट्रियता', 'सम्बन्धी', 'समस्याहरू', 'थाती', 'राख्ने', 'र', 'थुपार्ने', 'काम', 'निरन्तर', 'हुँदै', 'आइरहेका', 'छन्', 'अझ', 'प्रजातन्त् ...
# Words after removing stopwords
# ['वर्षपछि', 'मुलुकमा', 'राजाको', 'पञ्चायती', 'व्यवस्थाको', 'अवसान', 'बहुदलीय', 'व्यवस्थाको', 'उदय', 'सुखद', 'घडीको', 'पृष्ठभूमिमा', 'नेपाली', 'आमाका', 'सयौं', 'सपुतहरूले', 'प्रजातन्त्रको', 'बलिबेदीमा', 'अमूल्य', 'जीवन', 'न्यौछावर', 'तपाईँ', 'हाम्रै', 'निरङ्कुश', 'व्यवस्थाको', 'पोल', 'खोल्ने', 'जीवन्त', 'साक्षीहरूको', 'रूपमा', 'यातना', 'शिविरबाट', 'फर्केका', 'कैयौं', 'अपाङ्गहरू', 'छँदैछन्', 'प्रजातान्त्रिक', 'लडाइँलाई', 'निरन्तरता', 'दिने', 'क्रममा', 'तपाईँ', 'हाम्रै', 'गाउँघरमा', 'कैयन्', 'घरबारहरू', 'राजनीतिक', 'कारणले', 'बेहाल', 'बनाइएका', 'जनताको', 'अनवरत', 'सङ्घर्ष', 'खासगरी', 'अघिल्लो', 'वर्ष', 'राजनीतिक', 'विचारधारा', 'बर्ग', 'धर्म', 'पेसा', 'जात', 'जातिको', 'भेदभाव', 'नराखी', 'ढिको', 'ढिकको', 'नेपाली', 'जनताको', 'जुझारू', 'निर्णायक', 'सङ्घर्षले', 'वर्षसम्म', 'एकछत्र', 'रजाइँ', 'दलीय', 'तानाशाही', 'व्यवस्थालाई', 'लत्\u200cर्याइयो', 'अथाह', 'कष्ट', 'असह्य', 'यातना', 'निर्मम', 'शोषणमाथि', 'बनेको', 'निरङ्कुशताको', 'महल', 'रहेन', 'वर्षपछि', 'नेपाली', 'जनता', 'बहुदलीय', 'प्रतिस्पर्धात्मक', 'वातावरणमा', 'आम', 'चुनावमा', 'पाइ', 'सुखद', 'अवसरमा', 'प्रजातान्त्रिक', 'जनमञ्च', 'निरङ्कुशता', 'फाल्न', 'प्रजातन्त्र', 'ल्याउन', 'सहादत', 'हुनुहुने', 'तमाम', 'शहीदहरूमा', 'कृतज्ञता', 'पूर्वक', 'श्रद्धाञ्जली', 'अर्पण', 'विजयमा', 'नेपाली', 'जनताको', 'अजेय', 'पौरख', 'अभिव्यक्त', 'समस्त', 'नेपाली', 'जनतालाई', 'हार्दिक', 'अभिवादन', 'लामो', 'प्रजातान्त्रिक', 'सङ्घर्षमा', 'सहभागी', 'हुनुहुने', 'तमाम', 'योद्धाहरू', 'धन्यवादका', 'पात्र', 'आन्दोलनमा', 'विदेशी', 'मित्रहरूको', 'न्यानो', 'नैतिक', 'समर्थनले', 'आन्दोलनको', 'सफलताको', 'उर्जाको', 'गर्\u200dयो', 'समस्त', 'विदेशी', 'मित्रहरूको', 'दिशामा', 'भूमिका', 'योगदानको', 'उच्च', 'मूल्याङ्कन', 'गर्दछौ', 'पवन', 'घडीमा', 'वहाँहरू', 'आभार', 'प्रकट', 'गर्दछौँ', 'प्रजातान्त्रिक', 'जनमञ्च', 'नेपालमा', 'अहिलेसम्म', 'बनेका', 'राजनीतिक', 'सङ्गठनमा', 'सबभन्दा', 'कान्छो', 'सङ्गठन', 'गत', 'माघ', 'गते', 'विभिन्न', 'क्षेत्रमा', 'कार्यरत', 'राजनीतिक', 'व्यक्तिहरूको', 'आपसी', 'छलफल', 'विचार', 'विनिमयको', 'स्वाभाविक', 'निष्कर्ष', 'जनमञ्च', 'राजनीतिक', 'पार्टीको', 'रूपमा', 'विकास', 'नभइसकेको', 'छिटो', 'अवधिमा', 'जति', 'जन', 'अभिरुचि', 'समर्थन', 'सहभागिता', 'पाउन', 'सकेको', 'जनमञ्चको', 'नवीन', 'धाराको', 'औचित्यलाई', 'पुष्टि', 'मूल्य', 'चुकाएर', 'प्राप्त', 'प्रजातान्त्रिक', 'उपलब्धिलाई', 'सुदृढ', 'प्रवर्द्धन', 'हिजोभन्दा', 'सतर्क', 'जिम्मेवारीका', 'लाग्नु', 'नेपालीहरूको', 'परम', 'दायित्व', 'प्रजातन्त्रअभिव्यक्ति', 'स्वतन्त्रता', 'सङ्गठन', 'अधिकार', 'जनताको', 'गुणस्तरमा', 'सुधार', 'ल्याउन', 'सक्नु', 'पर्दछ', 'हिजोको', 'शासनले', 'विकास', 'श्रीलङ्कामा', 'पुछारमा', 'छाडेन', 'आम', 'गरिबी', 'चरम', 'विषमता', 'व्यापक', 'बेरोजगारी', 'विरासतमा', 'छाडेको', 'मुलुकको', 'हालत', 'बेवारिसे', 'वालकको', 'लथालिङ्ग', 'आर्थिक', 'सामाजिक', 'क्षेत्रमा', 'प्रजातान्त्रिक', 'पुनर्गठन', 'चुनौतीपूर्ण', 'कार्य', 'जनताको', 'आर्थिक', 'सामाजिक', 'जीवनमा', 'व्यापक', 'सुधार', 'ल्याएर', 'प्रजातन्त्रलाई', 'सुदृढ', 'दिगो', 'बनाउन', 'सकिन्छ', 'साँचो', 'अर्थमा', 'प्रजातन्त्रलाई', '"जनताको', 'जनताद्वारा', 'जनताको', 'सरकार"', 'अनुवाद', 'सकिन्छ', 'गरिबीले', 'राष्ट्रिय', 'स्वाभीमान', 'अस्मितालाई', 'निर्बल', 'बनाएको', 'छँदैछ', 'त्यसमाथि', 'राष्ट्रियता', 'सम्बन्धी', 'समस्याहरू', 'थाती', 'राख्ने', 'थुपार्ने', 'निरन्तर', 'हुँदै', 'आइरहेका', 'अझ', 'प्रजातन्त्रको', 'नाममा', 'राष्ट्रिय', 'हितलाई', 'किञ्चित्', 'आँच', 'आउने', 'विषयमा', 'राष्ट्रिय', 'जागरुकता', 'आवश्यक', 'बनेको', 'राष्ट्रिय', 'सङ्कल्प', 'साहसका', 'विदेशसँगको', 'सम्बन्धलाई', 'पञ्चशीलका', 'सिद्धान्तका', 'आधारमा', 'सुव्यवस्थित', 'पर्दछ', 'भूराजनीतिक', 'अवस्थाले', 'तर्कसङ्गत', 'लचिलो', 'विदेशनीति', 'अवलम्वन', 'प्रेरित', 'अर्थ', 'स्वतन्त्र', 'राष्ट्रिय', 'व्यक्तित्व', 'विकासमा', 'आँच', 'पुर्\u200dयाउने', 'राष्ट्रिय', 'हितलाई', 'बहानामा', 'सौदाबाजी', 'हुनुहुँदैन', 'हामीबाट', 'खास', 'चीन', 'भारतसँगको', 'सम्बन्धमा', 'सन्तुलित', 'सतर्क', 'ढङ्गले', 'घनिष्ट', 'रूपमा', 'समान', 'व्यवहार', 'गरिनु', 'पर्दछ', 'प्रजातन्त्रको', 'विकास', 'प्रकृयामा', 'नितान्त', 'सुषुप्त', 'अवस्थामा', 'देशवासीलाई', 'मानवजातिको', 'अथक', 'सङ्घर्ष', 'सभ्यताले', 'सिर्जेका', 'परिष्कृत', 'गरिएका', 'आधुनिकतम', 'मानव', 'मूल्य', 'अनुसरण', 'सक्षम', 'तुल ...

# %%
tokens3
# Out:
# ['वर्षपछि',
#  'मुलुकमा',
#  'राजाको',
#  'पञ्चायती',
#  'व्यवस्थाको',
#  'अवसान',
#  'बहुदलीय',
#  'व्यवस्थाको',
#  'उदय',
#  'सुखद',
#  'घडीको',
#  'पृष्ठभूमिमा',
#  'नेपाली',
#  'आमाका',
#  'सयौं',
#  'सपुतहरूले',
#  'प्रजातन्त्रको',
#  'बलिबेदीमा',
#  'अमूल्य',
#  'जीवन',
#  'न्यौछावर',
#  'तपाईँ',
#  'हाम्रै',
#  'निरङ्कुश',
#  'व्यवस्थाको',
#  'पोल',
#  'खोल्ने',
#  'जीवन्त',
#  'साक्षीहरूको',
#  'रूपमा',
#  'यातना',
#  'शिविरबाट',
#  'फर्केका',
#  'कैयौं',
#  'अपाङ्गहरू',
#  'छँदैछन्',
#  'प्रजातान्त्रिक',
#  'लडाइँलाई',
#  'निरन्तरता',
#  'दिने',
#  'क्रममा',
#  'तपाईँ',
#  'हाम्रै',
#  'गाउँघरमा',
#  'कैयन्',
#  'घरबारहरू',
#  'राजनीतिक',
#  'कारणले',
#  'बेहाल',
#  'बनाइएका',
#  'जनताको',
#  'अनवरत',
#  'सङ्घर्ष',
#  'खासगरी',
#  'अघिल्लो',
#  'वर्ष',
#  'राजनीतिक',
#  'विचारधारा',
#  'बर्ग',
#  'धर्म',
#  'पेसा',
#  'जात',
#  'जातिको',
#  'भेदभाव',
#  'नराखी',
#  'ढिको',
#  'ढिकको',
#  'नेपाली',
#  'जनताको',
#  'जुझारू',
#  'निर्णायक',
#  'सङ्घर्षले',
#  'वर्षसम्म',
#  'एकछत्र',
#  'रजाइँ',
#  'दलीय',
#  'तानाशाही',
#  'व्यवस्थालाई',
#  'लत्\u200cर्याइयो',
#  'अथाह',
#  'कष्ट',
#  'असह्य',
#  'यातना',
#  'निर्मम',
#  'शोषणमाथि',
#  'बनेको',
#  'निरङ्कुशताको',
#  'महल',
#  'रहेन',
#  'वर्षपछि',
#  'नेपाली',
#  'जनता',
#  'बहुदलीय',
#  'प्रतिस्पर्धात्मक',
#  'वातावरणमा',
#  'आम',
#  'चुनावमा',
#  'पाइ',
#  'सुखद',
#  'अवसरमा',
#  'प्रजातान्त्रिक',
#  'जनमञ्च',
#  'निरङ्कुशता',
#  'फाल्न',
#  'प्रजातन्त्र',
#  'ल्याउन',
#  'सहादत',
#  'हुनुहुने',
#  'तमाम',
#  'शहीदहरूमा',
#  'कृतज्ञता',
#  'पूर्वक',
#  'श्रद्धाञ्जली',
#  'अर्पण',
#  'विजयमा',
#  'नेपाली',
#  'जनताको',
#  'अजेय',
#  'पौरख',
#  'अभिव्यक्त',
#  'समस्त',
#  'नेपाली',
#  'जनतालाई',
#  'हार्दिक',
#  'अभिवादन',
#  'लामो',
#  'प्रजातान्त्रिक',
#  'सङ्घर्षमा',
#  'सहभागी',
#  'हुनुहुने',
#  'तमाम',
#  'योद्धाहरू',
#  'धन्यवादका',
#  'पात्र',
#  'आन्दोलनमा',
#  'विदेशी',
#  'मित्रहरूको',
#  'न्यानो',
#  'नैतिक',
#  'समर्थनले',
#  'आन्दोलनको',
#  'सफलताको',
#  'उर्जाको',
#  'गर्\u200dयो',
#  'समस्त',
#  'विदेशी',
#  'मित्रहरूको',
#  'दिशामा',
#  'भूमिका',
#  'योगदानको',
#  'उच्च',
#  'मूल्याङ्कन',
#  'गर्दछौ',
#  'पवन',
#  'घडीमा',
#  'वहाँहरू',
#  'आभार',
#  'प्रकट',
#  'गर्दछौँ',
#  'प्रजातान्त्रिक',
#  'जनमञ्च',
#  'नेपालमा',
#  'अहिलेसम्म',
#  'बनेका',
#  'राजनीतिक',
#  'सङ्गठनमा',
#  'सबभन्दा',
#  'कान्छो',
#  'सङ्गठन',
#  'गत',
#  'माघ',
#  'गते',
#  'विभिन्न',
#  'क्षेत्रमा',
#  'कार्यरत',
#  'राजनीतिक',
#  'व्यक्तिहरूको',
#  'आपसी',
#  'छलफल',
#  'विचार',
#  'विनिमयको',
#  'स्वाभाविक',
#  'निष्कर्ष',
#  'जनमञ्च',
#  'राजनीतिक',
#  'पार्टीको',
#  'रूपमा',
#  'विकास',
#  'नभइसकेको',
#  'छिटो',
#  'अवधिमा',
#  'जति',
#  'जन',
#  'अभिरुचि',
#  'समर्थन',
#  'सहभागिता',
#  'पाउन',
#  'सकेको',
#  'जनमञ्चको',
#  'नवीन',
#  'धाराको',
#  'औचित्यलाई',
#  'पुष्टि',
#  'मूल्य',
#  'चुकाएर',
#  'प्राप्त',
#  'प्रजातान्त्रिक',
#  'उपलब्धिलाई',
#  'सुदृढ',
#  'प्रवर्द्धन',
#  'हिजोभन्दा',
#  'सतर्क',
#  'जिम्मेवारीका',
#  'लाग्नु',
#  'नेपालीहरूको',
#  'परम',
#  'दायित्व',
#  'प्रजातन्त्रअभिव्यक्ति',
#  'स्वतन्त्रता',
#  'सङ्गठन',
#  'अधिकार',
#  'जनताको',
#  'गुणस्तरमा',
#  'सुधार',
#  'ल्याउन',
#  'सक्नु',
#  'पर्दछ',
#  'हिजोको',
#  'शासनले',
#  'विकास',
#  'श्रीलङ्कामा',
#  'पुछारमा',
#  'छाडेन',
#  'आम',
#  'गरिबी',
#  'चरम',
#  'विषमता',
#  'व्यापक',
#  'बेरोजगारी',
#  'विरासतमा',
#  'छाडेको',
#  'मुलुकको',
#  'हालत',
#  'बेवारिसे',
#  'वालकको',
#  'लथालिङ्ग',
#  'आर्थिक',
#  'सामाजिक',
#  'क्षेत्रमा',
#  'प्रजातान्त्रिक',
#  'पुनर्गठन',
#  'चुनौतीपूर्ण',
#  'कार्य',
#  'जनताको',
#  'आर्थिक',
#  'सामाजिक',
#  'जीवनमा',
#  'व्यापक',
#  'सुधार',
#  'ल्याएर',
#  'प्रजातन्त्रलाई',
#  'सुदृढ',
#  'दिगो',
#  'बनाउन',
#  'सकिन्छ',
#  'साँचो',
#  'अर्थमा',
#  'प्रजातन्त्रलाई',
#  '"जनताको',
#  'जनताद्वारा',
#  'जनताको',
#  'सरकार"',
#  'अनुवाद',
#  'सकिन्छ',
#  'गरिबीले',
#  'राष्ट्रिय',
#  'स्वाभीमान',
#  'अस्मितालाई',
#  'निर्बल',
#  'बनाएको',
#  'छँदैछ',
#  'त्यसमाथि',
#  'राष्ट्रियता',
#  'सम्बन्धी',
#  'समस्याहरू',
#  'थाती',
#  'राख्ने',
#  'थुपार्ने',
#  'निरन्तर',
#  'हुँदै',
#  'आइरहेका',
#  'अझ',
#  'प्रजातन्त्रको',
#  'नाममा',
#  'राष्ट्रिय',
#  'हितलाई',
#  'किञ्चित्',
#  'आँच',
#  'आउने',
#  'विषयमा',
#  'राष्ट्रिय',
#  'जागरुकता',
#  'आवश्यक',
#  'बनेको',
#  'राष्ट्रिय',
#  'सङ्कल्प',
#  'साहसका',
#  'विदेशसँगको',
#  'सम्बन्धलाई',
#  'पञ्चशीलका',
#  'सिद्धान्तका',
#  'आधारमा',
#  'सुव्यवस्थित',
#  'पर्दछ',
#  'भूराजनीतिक',
#  'अवस्थाले',
#  'तर्कसङ्गत',
#  'लचिलो',
#  'विदेशनीति',
#  'अवलम्वन',
#  'प्रेरित',
#  'अर्थ',
#  'स्वतन्त्र',
#  'राष्ट्रिय',
#  'व्यक्तित्व',
#  'विकासमा',
#  'आँच',
#  'पुर्\u200dयाउने',
#  'राष्ट्रिय',
#  'हितलाई',
#  'बहानामा',
#  'सौदाबाजी',
#  'हुनुहुँदैन',
#  'हामीबाट',
#  'खास',
#  'चीन',
#  'भारतसँगको',
#  'सम्बन्धमा',
#  'सन्तुलित',
#  'सतर्क',
#  'ढङ्गले',
#  'घनिष्ट',
#  'रूपमा',
#  'समान',
#  'व्यवहार',
#  'गरिनु',
#  'पर्दछ',
#  'प्रजातन्त्रको',
#  'विकास',
#  'प्रकृयामा',
#  'नितान्त',
#  'सुषुप्त',
#  'अवस्थामा',
#  'देशवासीलाई',
#  'मानवजातिको',
#  'अथक',
#  'सङ्घर्ष',
#  'सभ्यताले',
#  'सिर्जेका',
#  'परिष्कृत',
#  'गरिएका',
#  'आधुनिकतम',
#  'मानव',
#  'मूल्य',
#  'अनुसरण',
#  'सक्षम',
#  'तुल्याउनु',
#  'पर्दछ',
#  'व्यक्तिगत',
#  'स्वतन्त्रता',
#  'सामाजिक',
#  'उत्तरदायित्वको',
#  'आदर्शतम',
#  'सन्तुलन',
#  'मानव',
#  'सभ्यता',
#  'मानव',
#  'प्रगतिको',
#  'अन्तरलुप्\u200dत',
#  'रहस्य',
#  'विवादको',
#  'विषय',
#  'रहेन',
#  'व्यक्तिगत',
#  'स्वतन्त्रताको',
#  'उपयोग',
#  'सामाजिक',
#  'उत्तरदायित्वको',
#  'हेक्का',
#  'राखिनु',
#  'पर्दछ',
#  'भविष्य',
#  'विकल्प',
#  'राष्\u200dट्रवादी',
#  'प्रजातान्त्रिक',
#  'विकल्प',
#  'घोषित',
#  'लक्ष',
#  'प्रतिको',
#  'निष्\u200dठा',
#  'प्रतिवद्धताको',
#  'गहनाले',
#  'यथास्थिति',
#  'सीमालाई',
#  'नाघ्दछ',
#  'वर्तमान',
#  'सामाजिक',
#  'आर्थिक',
#  'संरचना',
#  'संस्थाबाट',
#  'द्रुततर',
#  'सामग्रिक',
#  'विकासको',
#  'आकाङ्क्षा',
#  'फलीभूत',
#  'प्रजातान्त्रिक',
#  'ढङ्गले',
#  'क्षेत्रमा',
#  'विकासलाई',
#  'गति',
#  'दिने',
#  'परिवर्तन',
#  'ल्याउनु',
#  'पर्दछ',
#  'प्रजातान्त्रिक',
#  'जनमञ्चले',
#  'सामाजिक',
#  'आर्थिक',
#  'क्रान्तिको',
#  'बिगुल',
#  'फुक्दै',
#  'आमूल',
#  'परिवर्तन',
#  'कारी',
#  'प्रजातान्त्रिक',
#  'विकल्पको',
#  'अवधारणा',
#  'सारेको',
#  'स्थापित',
#  'राजनीतिक',
#  'शक्तिहरूबाट',
#  'राष्\u200dट्रवादी',
#  'प्रजातान्त्रिक',
#  'अभिभारा',
#  'सम्पन्न',
#  'आशा',
#  'राख्ने',
#  'ठाउँ',
#  'राजाको',
#  'शक्तिले',
#  'मुलुकलाई',
#  'निरङ्कुशतामा',
#  'जकडेको',
#  'नभएर',
#  'आर्थिक',
#  'सामाजिक',
#  'रूपमा',
#  'रसातलमा',
#  'पुर्\u200dयाइ',
#  'दियो',
#  'राजनीतिक',
#  'नेतृत्व',
#  'शक्ति',
#  'कुलको',
#  'सार्वकालिक',
#  'रूपमा',
#  'सुरक्षित',
#  'विषय',
#  'सत्तामा',
#  'राजनीतिक',
#  'एकाधिकारको',
#  'नाम',
#  'तानाशाही',
#  'निरङ्कुश',
#  'तन्त्र',
#  'जनताको',
#  'नाममा',
#  'पार्टी',
#  'नोकरशाहहरूले',
#  'प्रजातन्त्रको',
#  'नाममा',
#  'सम्भ्रान्तहरूले',
#  'शासन',
#  'परिपाटी',
#  'अभिशापपूर्ण',
#  'तथ्य',
#  'सामु',
#  'छर्लङ्ग',
#  'सत्तामा',
#  'राजनीतिक',
#  'नेतृत्व',
#  'आवधिक',
#  'रूपमा',
#  'जनताको',
#  'अनुमोदन',
#  'लिई',
#  'रहनु',
#  'पर्दछ',
#  'प्रतिस्पर्धालाई',
#  'स्विकार्नु',
#  'पर्दछ',
#  'अर्कोतिर',
#  'सत्ता',
#  'लिप्साको',
#  'राष्ट्रिय',
#  'स्वार्थलाई',
#  'गौण',
#  'सौदाबाजीको',
#  'विषय',
#  'बनाउने',
#  'राष्ट्रिय',
#  'हितको',
#  'जगेर्ना',
#  'पराई',
#  'मुलुकको',
#  'हितमा',
#  'वकालत',
#  'प्रवृत्ति',
#  'राजनीतिक',
#  'शक्तिहरूमा',
#  'छदैछ',
#  'राजनीतिक',
#  'नेतृत्वको',
#  'खाँचो',
#  'परेको',
#  'प्रजातान्त्रिक',
#  'जनमञ्च',
#  'दिशामा',
#  'प्रारंभिक',
#  'पाइलो',
#  'सवल',
#  'प्रजातान्त्रिक',
#  'विकल्प',
#  'विकासको',
#  'कृतसङ्कल्पित',
#  'जातीय',
#  'भौगोलिक',
#  'बनोटको',
#  'हिसाबले',
#  'देश',
#  'भिन्नताको',
#  'मेल',
#  'बिभिन्न',
#  'जातजाति',
#  'भाषाभाषी',
#  'उनीहरूको',
#  'आ',
#  'परम्परा',
#  'संस्कृतिले',
#  'नेपाललाई',
#  '"सयौं',
#  'फूलहरूको',
#  'फूलबारी"',
#  'बनाइ',
#  'धर्म',
#  'भाषा',
#  'भेष',
#  'भूषा',
#  'चाडबाड',
#  'रीतिरिवाज',
#  'चलन',
#  'परम्पराको',
#  'भिन्नताले',
#  'जातीय',
#  'अस्तित्व',
#  'बोकेको',
#  'नभएर',
#  'पारस्परिक',
#  'समझदारी',
#  'सदभाव',
#  'सहिष्णुता',
#  'एकताको',
#  'आदर्श',
#  'भावले',
#  'साझा',
#  'राष्ट्रिय',
#  'संस्कृतिको',
#  'धरोहर',
#  'खडा',
#  'हुँदाहुँदै',
#  'क्षेत्रमा',
#  'समस्याहरू',
#  'शासक',
#  'वर्गका',
#  'क्रियाकलापबाट',
#  'विभिन्न',
#  'जाती',
#  'भाषा',
#  'संस्कृति',
#  'विभेद',
#  'सामाजिक',
#  'विकासका',
#  'प्रवाहमा',
#  'कतिपय',
#  'जातिहरू',
#  'खास',
#  'जनजातिहरू',
#  'परेका',
#  'असमान',
#  'जातीय',
#  'विकासले',
#  'सृजेका',
#  'समस्याहरू',
#  'थाती',
#  'राखेर',
#  'उपेक्षा',
#  'राख्न',
#  'मिल्दैन',
#  'जनतामा',
#  'जातीय',
#  'भेदभावको',
#  'बोध',
#  'विकास',
#  'थालेपछि',
#  'भयावह',
#  'लिन्छ',
#  'छिमेकी',
#  'मुलुककै',
#  'विकासक्रमबाट',
#  'हेरे',
#  'प्रष्ट',
#  'आगामी',
#  'दिनमा',
#  'प्राथमिकताका',
#  'समाधान',
#  'समस्या',
#  'सबैले',
#  'बुझ्नु',
#  'जरुरी',
#  'समस्या',
#  'विद्यमान',
#  'नाउँमा',
#  'यसलाई',
#  'जातीय',
#  'मेलमिलाप',
#  'राष्ट्रिय',
#  'अखण्डतामा',
#  'खलल',
#  'पुग्ने',
#  'साम्प्रदायिकता',
#  'भडकाउने',
#  'राष्ट्रिय',
#  'विघटन',
#  'कार्यमा',
#  'सघाउ',
#  'पुर्\u200dयाउने',
#  'कार्य',
#  'अनुमति',
#  'हिजोको',
#  'निरङ्कुश',
#  'शासनको',
#  'काढेर',
#  'बसेकाहरू',
#  'जातीय',
#  'हितका',
#  'इसामसिह',
#  'खोजेको',
#  'हरकतलाई',
#  'खास',
#  'सम्बन्धित',
#  'क्षेत्रबाट',
#  'स्यालको',
#  'निरर्थक',
#  'धुर्त्याई',
#  'बुझ्न',
#  'बुझाउन',
#  'जरुरी',
#  'यसै',
#  'भौगोलिक',
#  'बनोटका',
#  'अतिरिक्त',
#  'शासक',
#  'वर्गहरूको',
#  'असन्तुलित',
#  'नीति',
#  'सीमान्त',
#  'क्षेत्रको',
#  'शोषणबाट',
#  'केन्द्र',
#  'सिंगार्ने',
#  'नीतिले',
#  'क्षेत्रीय',
#  'विकासमा',
#  'जवर्जस्त',
#  'असन्तुलन',
#  'कायम',
#  'दुर्गम',
#  'पहाडी',
#  'क्षेत्र',
#  'सुदूर',
#  'पश्चिम',
#  'इलाका',
#  'विकास',
#  'प्रवाहमा',
#  'समाहित',
#  'सकेका',
#  'सिमान्त',
#  'क्षेत्रको',
#  'तराई',
#  'जर्जर',
#  'उजाड',
#  'असन्तुलनलाई',
#  'थेग्न',
#  'सक्छौँ',
#  'उप्रान्त',
#  'विकास',
#  'सम्बन्धी',
#  'नीति',
#  'कार्यक्रम',
#  'परियोजना',
#  'तर्जुमा',
#  'सञ्चालन',
#  'असन्तुलनलाई',
#  'नजर',
#  'राखेर',
#  'सञ्चालन',
#  'गरिनु',
#  'पर्दछ',
#  'पिछडिएका',
#  'क्षेत्रमा',
#  'प्राथमिकता',
#  'दिनु',
#  'पर्दछ',
#  'आदरणीय',
#  'देशवासीहरू',
#  'आमा',
#  'निर्वाचनको',
#  'नजिकिंदै',
#  'कम्तीमा',
#  'राष्ट्रलाई',
#  'आगामी',
#  'वर्षका',
#  'दिशा',
#  'दिने',
#  'निर्वाचनबाट',
#  'गठित',
#  'संसद',
#  'सरकारले',
#  'संसद',
#  'सरकारको',
#  'बनोटलाई',
#  'विद्यमान',
#  'पार्टी',
#  'उनीहरूको',
#  'प्रत्यासीहरूले',
#  'प्रभावित',
#  'हुँदा',
#  'उनीहरूप्रति',
#  'मोटामोटी',
#  'रूपमा',
#  'विचार',
#  'बनाउनु',
#  'जरुरी',
#  'मूलतः',
#  'निर्वाचनमा',
#  'राजनीतिक',
#  'शक्तिहरू',
#  'क्रियाशील',
#  '\n',
#  'राजाको',
#  'पञ्चायती',
#  'शक्ति',
#  'बहुदलीय',
#  'व्यवस्था',
#  'पुनर्स्थापनको',
#  'लगत्तै',
#  'एकै',
#  'झण्डा',
#  'बोकि',
#  'नाममा',
#  'खुलेका',
#  'दुईवटा',
#  'राष्ट्रिय',
#  'प्रजातन्त्र',
#  'पार्टी',
#  'राजा',
#  'राजदरबारकै',
#  'जुम्ल्याहा',
#  'बच्चा',
#  'भन्नुमा',
#  'अत्युक्ति',
#  'नहोला',
#  'पञ्चायतको',
#  'परिवर्तित',
#  'रूपलाई',
#  'यिनीहरूले',
#  'प्रतिनिधित्व',
#  'गर्दछन्',
#  'यिनीहरूले',
#  'विगत',
#  'वर्षमा',
#  'कयौं',
#  'राजाको',
#  'सकृय',
#  'नेतृत्वको',
#  'कसम',
#  'खाएका',
#  'राजा',
#  'त्यसैगरी',
#  'नाचेका',
#  'निर्दलीयताको',
#  'नाममा',
#  'निर्मन',
#  'दमनबाट',
#  'चलेको',
#  'तानाशाही',
#  'शासन',
#  'उनीहरूको',
#  'पुर्ख्यौली',
#  'राजनीतिक',
#  'सम्पत्ति',
#  'शोषण',
#  'विहिन्',
#  'समाज',
#  'निर्माण',
#  'नाममा',
#  'उनीहरूले',
#  'राष्ट्रको',
#  'सर्वस्व',
#  'लुटेका',
#  'अथाह',
#  'सम्पाति',
#  'विदेशमा',
#  'थुपारेका',
#  'वर्षको',
#  'उनीहरूको',
#  'कुकर्मलाई',
#  'हेरेर',
#  'इतिहासले',
#  'निर्णय',
#  'त्यसलाई',
#  'राज्यसत्ता',
#  'ब्रह्मलुटको',
#  'सम्पत्तिले',
#  'उल्ट्\u200dयाउन',
#  'उनीहरू',
#  'भरमग्दुर',
#  'लागेका',
#  'इतिहासको',
#  'पाङ्ग्रालाई',
#  'धकेल्ने',
#  'उनीहरूका',
#  'दुश्\u200dचेष्\u200dटा',
#  'किमार्थ',
#  'सफल',
#  'अन्तरिम',
#  'मन्त्रिमण्डलले',
#  'जनादेशको',
#  'शाहसपूर्वक',
#  'कार्यान्वयन',
#  'नसकेर',
#  'उनीहरू',
#  'छाती',
#  'खोल्न',
#  'पाइरहेका',
#  'इतिहासको',
#  'निर्णयलाई',
#  'बदर',
#  'गराउन',
#  'खोज्ने',
#  'शक्तिलाई',
#  'आगामी',
#  'निर्वाचनले',
#  'ङ्याक्नु',
#  'पर्दछ',
#  'पुनः',
#  'तानाशाही',
#  'शक्ति',
#  'शिर',
#  'उठाउने',
#  'हिम्मत',
#  'नसकोस्',
#  '\n.',
#  'नेपाली',
#  'काँग्रेस',
#  'राजाको',
#  'निरङ्कुशताको',
#  'रूपमा',
#  'पञ्चायती',
#  'व्यवस्थालाई',
#  'मास्न',
#  'बहुदलीय',
#  'व्यवस्थाको',
#  'स्थापनाको',
#  'नेपाली',
#  'काङ्ग्रेसले',
#  'योगदान',
#  'सराहनीय',
#  'पञ्चायत',
#  'विरोधी',
#  'आन्दोलनकारी',
#  'शक्तिहरूसँगको',
#  'संयुक्त',
#  'आन्दोलनको',
#  'विरोध',
#  'खासगरी',
#  'दशकमा',
#  'आएर',
#  'निरङ्कुश',
#  'राजतन्त्रसँगको',
#  'मेलमिलापको',
#  'नीतिले',
#  'पञ्चायतको',
#  'आयु',
#  'यतिसम्म',
#  'लामो',
#  'जन',
#  'आन्दोलनमा',
#  'आन्दोलनको',
#  'उद्\u200dघोष',
#  'तालमेल',
#  'कै',
#  'हदसम्म',
#  'संयुक्त',
#  'आन्दोलनमा',
#  'आउने',
#  'निर्णय',
#  'प्रजातान्त्रिक',
#  'आन्दोलनको',
#  'विकासको',
#  'निर्णायक',
#  'मोड',
#  'पुग्यो',
#  'आन्दोलनको',
#  'सफलता',
#  'कम्युनिष्ट',
#  'राजाको',
#  'शक्तिलाई',
#  'साथमा',
#  'लिएर',
#  'सत्ता',
#  'सम्हाले',
#  'चरित्रगत',
#  'कारणले',
#  'राजाको',
#  'निरङ्कुशतामा',
#  'हुर्केका',
#  'राजनीतिक',
#  'आर्थिक',
#  'अपराधीहरूलाई',
#  'कार्यवाही',
#  'गर्नमा',
#  'उदासीनता',
#  'देखाएन',
#  'जघन्य',
#  'अपराधीहरूलाई',
#  'छोड्ने',
#  'हास्यास्पद',
#  'सङ्कोच',
#  'मानेन',
#  'पार्टीभित्र',
#  'राष्ट्रियता',
#  'प्रजातन्त्र',
#  'विरोधी',
#  'शक्तिले',
#  'प्रश्रय',
#  'पाइरहेका',
#  'हिजोका',
#  'वरिष्ठ',
#  'पञ्चहरूले',
#  'प्रवेश',
#  'पाएका',
#  'प्रबल',
#  'पार्टी',
#  'ब्युरोक्रेसी',
#  'आन्तरिक',
#  'प्रजातन्त्रको',
#  'अभावको',
#  'पार्टीका',
#  'स्वयम्',
#  'कार्यकर्ताहरू',
#  'आवाज',
#  'उठाइरहेका',
#  '"चीनसँग',
#  'मित्रता',
#  'भारतसँग',
#  'घनिष्\u200dटता"',
#  'घोषित',
#  'नीतिको',
#  'दुष्परिणामहरू',
#  'प्रकट',
#  'थालेका',
#  'सन्धिको',
#  'अन्यायपूर्ण',
#  'प्रावधानले',
#  'राष्ट्रिय',
#  'स्वार्थ',
#  'स्वाभीमानलाई',
#  'किचिरहेको',
#  'बोझहरू',
#  'थपिँदै',
#  'कोशी',
#  'गण्डकी',
#  'सम्झौतामा',
#  'राष्ट्रिय',
#  'कलङ्क',
#  'ठगिएको',
#  'घाउ',
#  'आलै',
#  'भारत',
#  ...]

# %%
# tokens3=['वर्षपछि']
len(tokens3)
# Out:
# 1404

# %%
from stemmer import Stemmer

# %%
m=Stemmer()

# %%
rep,i,k,repc=0,0,0,0
tokens=tokens3
new=[]
unrecog=[]
count=1
for token in tokens:
    p="yes"
    i,k = 0,0 #no. of suffix and prefix found
    print("\nUnstemmed input token"+str(count)+":"+token)
    orig_token=token
    end=False
    while (not end):
        print("Checking root word or not")
        if (m.isRoot(token) or( m.isAltRoot(token) and i>0)):
            print("comdition1")
            if( m.isAltRoot(token) and i>0):
                m.setRoot(m.getAltRoot(token))
                
            else:
                m.setRoot(token)
                print("\nRoot word found:"+token)    
            end=True
            
        elif (m.isRoot(token + "\u094d")) :
            print("comdition2")

            i+=1
            m.setSMorph_number(i)
            m.isASuffix(token)
            token = m.getRoot()

            
        elif (token.endswith("\u094d") and m.isRoot(token[:len(token)-1])):
            print("comdition3")
            token=token[:len(token)-1]
            m.setRoot(token)

        elif (m.suffixPresent(token,i)) :
            print("comdition4")
            i+=1
            m.setSMorph_number(i)
            m.stripSuffix(token)
            token = m.getRoot()

        elif (m.prefixPresent(token)) :
            print("comdition5")
            k+=1
            m.setPMorph_number(k)
            m.stripPrefix(token)
            token = m.getRoot()
            
        else:
            print("\nRecombining suffix")
            
#           if prefix and suffix present
            if (k > 0 and i > 0) :
                print("comdition6:bot suffix and prefix found previously")

                a = m.getPMorph()
                print("PMorph:"+str(a))
                for k1 in range(k,0,-1):
                    tmp = token
                    for l in range(i,0,-1):
                        tm = m.generateWord(tmp, l)
                        print("generated word: "+tm)

                        if (m.isRoot(tm) or ( m.isAltRoot(tm) and i>0)):
                            bk = 1
                            m.setSMorph_number(l - 1)
                            m.setPMorph_number(k)
                            if(( m.isAltRoot(tm) and i>0)):
                                m.setRoot(m.getAltRoot(tm))
                            else:
                                m.setRoot(tm)
                            token = m.getRoot()
                            break
                        else:
                            bk = 0
                            tmp = tm
                    
                    if (bk == 1) :
                        break
                    

                    if (k1 > 1):
                        token = a[k1] + token

                
                if (bk != 1) :
                    m.setRoot("unrecognized")

                    k = 0
                

            else: 
                print("comdition7:unrecognized")

                m.setRoot("unrecognized")


            if (m.getRoot()==("unrecognized")):
                rep+=1

                repeat = 0
#               for the second parse
                if (rep == 1) :
#                   check for if the any rulenumber of the suffix contains repeat sign "Y"
                    for l in range(i,0,-1):
                        if (m.isRepeat(str(m.getSMorph_rulenum(l)))):
                            repeat = 1
                            break #//for any suffix that has a repeat sign.
                        else:
                            repeat = 0
                    
                
#               if any rulenumber has the suffix content as repeat sign"Y"
                if (repeat == 1) :
                    token = origtoken
                    m.setPMorph_number(0)
                    m.setSMorph_number(0)
                    i = 0
                    k = 0
                    m.setSecParse(rep)
                else:
                    break
    if(m.getRoot()==("unrecognized")):
        unrecog.append(orig_token)
        new.append(orig_token)
        print("\nfinal token (couldnt stem):"+orig_token)
        
    else:
        new.append(m.getRoot())
        print("\nfinal stemmed token:"+m.getRoot())
    count+=1
# Out:
# Unstemmed input token1:वर्षपछि
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:र्षपछि
# tmp_suffix:्षपछि
# tmp_suffix:षपछि
# tmp_suffix:पछि
# tmp_suffix:छि
# tmp_suffix:ि
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:63
#
# Suffix_del:आइ
#
# Suffix_del:ाइ
#
# Suffix_del:ि
# ि ्
# not_dot ्
#
# final stiped word: वर्षपछ्
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:र्षपछ्
# tmp_suffix:्षपछ्
# tmp_suffix:षपछ्
# tmp_suffix:पछ्
# tmp_suffix:छ्
# tmp_suffix:्
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:व
# tmp_prefix:वर
# tmp_prefix:वर्
# tmp_prefix:वर्ष
# tmp_prefix:वर्षप
# tmp_prefix:वर्षपछ
# tmp_prefix:वर्षपछ्
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):वर्षपछि
#
# Unstemmed input token2:मुलुकमा
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ुलुकमा
# tmp_suffix:लुकमा
# tmp_suffix:ुकमा
# tmp_suffix:कमा
# tmp_suffix:मा
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:57
#
# Suffix_del:मा
# मा .
#
# final stiped word: मुलुक
# Checking root word or not
# comdition1
#
# Root word found:मुलुक
#
# final stemmed token:मुलुक
#
# Unstemmed input token3:राजाको
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ाजाको
# tmp_suffix:जाको
# tmp_suffix:ाको
# tmp_suffix:को
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:4
#
# Suffix_del:को
# को .
#
# final stiped word: राजा
# Checking root word or not
# comdition1
#
# Root word found:राजा
#
# final stemmed token:राजा
#
# Unstemmed input token4:पञ्चायती
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ञ्चायती
# tmp_suffix:्चायती
# tmp_suffix:चायती
# tmp_suffix:ायती
# tmp_suffix:यती
# tmp_suffix:ती
# tmp_suffix:ी
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:61
#
# Suffix_del:ी
# ी ्
# not_dot ्
#
# final stiped word: पञ्चायत्
# Checking root word or not
# comdition3
# Checking root word or not
# comdition1
#
# Root word found:पञ्चायत
#
# final stemmed token:पञ्चायत
#
# Unstemmed input token5:व्यवस्थाको
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:्यवस्थाको
# tmp_suffix:यवस्थाको
# tmp_suffix:वस्थाको
# tmp_suffix:स्थाको
# tmp_suffix:्थाको
# tmp_suffix:थाको
# tmp_suffix:ाको
# tmp_suffix:को
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:4
#
# Suffix_del:को
# को .
#
# final stiped word: व्यवस्था
# Checking root word or not
# comdition1
#
# Root word found:व्यवस्था
#
# final stemmed token:व्यवस्था
#
# Unstemmed input token6:अवसान
# Checking root word or not
# comdition1
#
# Root word found:अवसान
#
# final stemmed token:अवसान
#
# Unstemmed input token7:बहुदलीय
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:हुदलीय
# tmp_suffix:ुदलीय
# tmp_suffix:दलीय
# tmp_suffix:लीय
# tmp_suffix:ीय
# tmp_suffix:य
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:ब
# tmp_prefix:बह
# tmp_prefix:बहु
# tmp_prefix:बहुद
# tmp_prefix:बहुदल
# tmp_prefix:बहुदली
# tmp_prefix:बहुदलीय
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):बहुदलीय
#
# Unstemmed input token8:व्यवस्थाको
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:्यवस्थाको
# tmp_suffix:यवस्थाको
# tmp_suffix:वस्थाको
# tmp_suffix:स्थाको
# tmp_suffix:्थाको
# tmp_suffix:थाको
# tmp_suffix:ाको
# tmp_suffix:को
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:4
#
# Suffix_del:को
# को .
#
# final stiped word: व्यवस्था
# Checking root word or not
# comdition1
#
# Root word found:व्यवस्था
#
# final stemmed token:व्यवस्था
#
# Unstemmed input token9:उदय
# Checking root word or not
# comdition1
#
# Root word found:उदय
#
# final stemmed token:उदय
#
# Unstemmed input token10:सुखद
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ुखद
# tmp_suffix:खद
# tmp_suffix:द
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:स
# tmp_prefix:सु
#
# prefix found
# comdition5
#
# Stripping prefix
# rule:5
#
# Prefix_del:सु
#
# final stiped word: खद
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:द
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:ख
# tmp_prefix:खद
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):सुखद
#
# Unstemmed input token11:घडीको
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:डीको
# tmp_suffix:ीको
# tmp_suffix:को
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:4
#
# Suffix_del:को
# को .
#
# final stiped word: घडी
# Checking root word or not
# comdition1
#
# Root word found:घडी
#
# final stemmed token:घडी
#
# Unstemmed input token12:पृष्ठभूमिमा
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ृष्ठभूमिमा
# tmp_suffix:ष्ठभूमिमा
# tmp_suffix:्ठभूमिमा
# tmp_suffix:ठभूमिमा
# tmp_suffix:भूमिमा
# tmp_suffix:ूमिमा
# tmp_suffix:मिमा
# tmp_suffix:िमा
# tmp_suffix:मा
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:57
#
# Suffix_del:मा
# मा .
#
# final stiped word: पृष्ठभूमि
# Checking root word or not
# comdition1
#
# Root word found:पृष्ठभूमि
#
# final stemmed token:पृष्ठभूमि
#
# Unstemmed input token13:नेपाली
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ेपाली
# tmp_suffix:पाली
# tmp_suffix:ाली
# tmp_suffix:ली
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:49
#
# Suffix_del:ली
# ली .
#
# final stiped word: नेपा
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ेपा
# tmp_suffix:पा
# tmp_suffix:ा
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:10
#
# Suffix_del:ा
# ा ्
# not_dot ्
#
# final stiped word: नेप्
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ेप्
# tmp_suffix:प्
# tmp_suffix:्
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:न
#
# prefix found
# comdition5
#
# Stripping prefix
# rule:1
#
# Prefix_del:न
#
# final stiped word: ेप्
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:प्
# tmp_suffix:्
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:े
# tmp_prefix:ेप
# tmp_prefix:ेप्
#
# prefix not found
#
# Recombining suffix
# comdition6:bot suffix and prefix found previously
# PMorph:['', 'न', 'न', '', '', '', '', '', '', '']
#
# generating word
# generated word: ेपा
#
# generating word
# generated word: ेपाली
#
# final token (couldnt stem):नेपाली
#
# Unstemmed input token14:आमाका
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:माका
# tmp_suffix:ाका
# tmp_suffix:का
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:5
#
# Suffix_del:का
# का .
#
# final stiped word: आमा
# Checking root word or not
# comdition1
#
# Root word found:आमा
#
# final stemmed token:आमा
#
# Unstemmed input token15:सयौं
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:यौं
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:44
#
# Suffix_del:यौं
# यौं .
#
# final stiped word: स
# Checking root word or not
#
# Checking suffix present or not
#
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:स
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):सयौं
#
# Unstemmed input token16:सपुतहरूले
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:पुतहरूले
# tmp_suffix:ुतहरूले
# tmp_suffix:तहरूले
# tmp_suffix:हरूले
# tmp_suffix:रूले
# tmp_suffix:ूले
# tmp_suffix:ले
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:3
#
# Suffix_del:ले
# ले .
#
# final stiped word: सपुतहरू
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:पुतहरू
# tmp_suffix:ुतहरू
# tmp_suffix:तहरू
# tmp_suffix:हरू
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:1
#
# Suffix_del:हरू
# हरू .
#
# final stiped word: सपुत
# Checking root word or not
# comdition1
#
# Root word found:सपुत
#
# final stemmed token:सपुत
#
# Unstemmed input token17:प्रजातन्त्रको
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:्रजातन्त्रको
# tmp_suffix:रजातन्त्रको
# tmp_suffix:जातन्त्रको
# tmp_suffix:ातन्त्रको
# tmp_suffix:तन्त्रको
# tmp_suffix:न्त्रको
# tmp_suffix:्त्रको
# tmp_suffix:त्रको
# tmp_suffix:्रको
# tmp_suffix:रको
# tmp_suffix:को
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:4
#
# Suffix_del:को
# को .
#
# final stiped word: प्रजातन्त्र
# Checking root word or not
# comdition1
#
# Root word found:प्रजातन्त्र
#
# final stemmed token:प्रजातन्त्र
#
# Unstemmed input token18:बलिबेदीमा
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:लिबेदीमा
# tmp_suffix:िबेदीमा
# tmp_suffix:बेदीमा
# tmp_suffix:ेदीमा
# tmp_suffix:दीमा
# tmp_suffix:ीमा
# tmp_suffix:मा
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:57
#
# Suffix_del:मा
# मा .
#
# final stiped word: बलिबेदी
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:लिबेदी
# tmp_suffix:िबेदी
# tmp_suffix:बेदी
# tmp_suffix:ेदी
# tmp_suffix:दी
# tmp_suffix:ी
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:61
#
# Suffix_del:ी
# ी ्
# not_dot ्
#
# final stiped word: बलिबेद्
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:लिबेद्
# tmp_suffix:िबेद्
# tmp_suffix:बेद्
# tmp_suffix:ेद्
# tmp_suffix:द्
# tmp_suffix:्
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:ब
# tmp_prefix:बल
# tmp_prefix:बलि
# tmp_prefix:बलिब
# tmp_prefix:बलिबे
# tmp_prefix:बलिबेद
# tmp_prefix:बलिबेद्
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):बलिबेदीमा
#
# Unstemmed input token19:अमूल्य
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:मूल्य
# tmp_suffix:ूल्य
# tmp_suffix:ल्य
# tmp_suffix:्य
# tmp_suffix:य
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:अ
#
# prefix found
# comdition5
#
# Stripping prefix
# rule:4
#
# Prefix_del:अ
#
# final stiped word: मूल्य
# Checking root word or not
# comdition1
#
# Root word found:मूल्य
#
# final stemmed token:मूल्य
#
# Unstemmed input token20:जीवन
# Checking root word or not
# comdition1
#
# Root word found:जीवन
#
# final stemmed token:जीवन
#
# Unstemmed input token21:न्यौछावर
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:्यौछावर
# tmp_suffix:यौछावर
# tmp_suffix:ौछावर
# tmp_suffix:छावर
# tmp_suffix:ावर
# tmp_suffix:वर
# tmp_suffix:र
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:न
#
# prefix found
# comdition5
#
# Stripping prefix
# rule:1
#
# Prefix_del:न
#
# final stiped word: ्यौछावर
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:यौछावर
# tmp_suffix:ौछावर
# tmp_suffix:छावर
# tmp_suffix:ावर
# tmp_suffix:वर
# tmp_suffix:र
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:्
# tmp_prefix:्य
# tmp_prefix:्यौ
# tmp_prefix:्यौछ
# tmp_prefix:्यौछा
# tmp_prefix:्यौछाव
# tmp_prefix:्यौछावर
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):न्यौछावर
#
# Unstemmed input token22:तपाईँ
# Checking root word or not
# comdition1
#
# Root word found:तपाईँ
#
# final stemmed token:तपाईँ
#
# Unstemmed input token23:हाम्रै
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ाम्रै
# tmp_suffix:म्रै
# tmp_suffix:्रै
# tmp_suffix:रै
# tmp_suffix:ै
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:83
#
# Suffix_del:ै
# ै ्
# not_dot ्
#
# final stiped word: हाम्र्
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ाम्र्
# tmp_suffix:म्र्
# tmp_suffix:्र्
# tmp_suffix:र्
# tmp_suffix:्
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:ह
# tmp_prefix:हा
# tmp_prefix:हाम
# tmp_prefix:हाम्
# tmp_prefix:हाम्र
# tmp_prefix:हाम्र्
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):हाम्रै
#
# Unstemmed input token24:निरङ्कुश
# Checking root word or not
# comdition1
#
# Root word found:निरङ्कुश
#
# final stemmed token:निरङ्कुश
#
# Unstemmed input token25:व्यवस्थाको
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:्यवस्थाको
# tmp_suffix:यवस्थाको
# tmp_suffix:वस्थाको
# tmp_suffix:स्थाको
# tmp_suffix:्थाको
# tmp_suffix:थाको
# tmp_suffix:ाको
# tmp_suffix:को
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:4
#
# Suffix_del:को
# को .
#
# final stiped word: व्यवस्था
# Checking root word or not
# comdition1
#
# Root word found:व्यवस्था
#
# final stemmed token:व्यवस्था
#
# Unstemmed input token26:पोल
# Checking root word or not
# comdition1
#
# Root word found:पोल
#
# final stemmed token:पोल
#
# Unstemmed input token27:खोल्ने
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ोल्ने
# tmp_suffix:ल्ने
# tmp_suffix:्ने
# tmp_suffix:ने
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:16
#
# Suffix_del:ने
# ने .
#
# final stiped word: खोल्
# Checking root word or not
# comdition1
#
# Root word found:खोल्
#
# final stemmed token:खोल्
#
# Unstemmed input token28:जीवन्त
# Checking root word or not
# comdition1
#
# Root word found:जीवन्त
#
# final stemmed token:जीवन्त
#
# Unstemmed input token29:साक्षीहरूको
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ाक्षीहरूको
# tmp_suffix:क्षीहरूको
# tmp_suffix:्षीहरूको
# tmp_suffix:षीहरूको
# tmp_suffix:ीहरूको
# tmp_suffix:हरूको
# tmp_suffix:रूको
# tmp_suffix:ूको
# tmp_suffix:को
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:4
#
# Suffix_del:को
# को .
#
# final stiped word: साक्षीहरू
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ाक्षीहरू
# tmp_suffix:क्षीहरू
# tmp_suffix:्षीहरू
# tmp_suffix:षीहरू
# tmp_suffix:ीहरू
# tmp_suffix:हरू
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:1
#
# Suffix_del:हरू
# हरू .
#
# final stiped word: साक्षी
# Checking root word or not
# comdition1
#
# Root word found:साक्षी
#
# final stemmed token:साक्षी
#
# Unstemmed input token30:रूपमा
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ूपमा
# tmp_suffix:पमा
# tmp_suffix:मा
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:57
#
# Suffix_del:मा
# मा .
#
# final stiped word: रूप
# Checking root word or not
# comdition1
#
# Root word found:रूप
#
# final stemmed token:रूप
#
# Unstemmed input token31:यातना
# Checking root word or not
# comdition1
#
# Root word found:यातना
#
# final stemmed token:यातना
#
# Unstemmed input token32:शिविरबाट
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:िविरबाट
# tmp_suffix:विरबाट
# tmp_suffix:िरबाट
# tmp_suffix:रबाट
# tmp_suffix:बाट
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:9
#
# Suffix_del:बाट
# बाट .
#
# final stiped word: शिविर
# Checking root word or not
# comdition1
#
# Root word found:शिविर
#
# final stemmed token:शिविर
#
# Unstemmed input token33:फर्केका
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:र्केका
# tmp_suffix:्केका
# tmp_suffix:केका
# tmp_suffix:ेका
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:11
#
# Suffix_del:ाएका
#
# Suffix_del:ेका
# ेका ्
# not_dot ्
#
# final stiped word: फर्क्
# Checking root word or not
# comdition3
# Checking root word or not
# comdition1
#
# Root word found:फर्क
#
# final stemmed token:फर्क
#
# Unstemmed input token34:कैयौं
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ैयौं
# tmp_suffix:यौं
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:44
#
# Suffix_del:यौं
# यौं .
#
# final stiped word: कै
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ै
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:83
#
# Suffix_del:ै
# ै ्
# not_dot ्
#
# final stiped word: क्
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:्
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:क
# tmp_prefix:क्
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):कैयौं
#
# Unstemmed input token35:अपाङ्गहरू
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:पाङ्गहरू
# tmp_suffix:ाङ्गहरू
# tmp_suffix:ङ्गहरू
# tmp_suffix:्गहरू
# tmp_suffix:गहरू
# tmp_suffix:हरू
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:1
#
# Suffix_del:हरू
# हरू .
#
# final stiped word: अपाङ्ग
# Checking root word or not
# comdition1
#
# Root word found:अपाङ्ग
#
# final stemmed token:अपाङ्ग
#
# Unstemmed input token36:छँदैछन्
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ँदैछन्
# tmp_suffix:दैछन्
# tmp_suffix:ैछन्
# tmp_suffix:छन्
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:31
#
# Suffix_del:ँछन्
#
# Suffix_del:छन्
# छन् .
#
# final stiped word: छँदै
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ँदै
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:19
#
# Suffix_del:ँदै
# ँदै .
#
# final stiped word: छ
# Checking root word or not
# comdition1
#
# Root word found:छ
#
# final stemmed token:छ
#
# Unstemmed input token37:प्रजातान्त्रिक
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:्रजातान्त्रिक
# tmp_suffix:रजातान्त्रिक
# tmp_suffix:जातान्त्रिक
# tmp_suffix:ातान्त्रिक
# tmp_suffix:तान्त्रिक
# tmp_suffix:ान्त्रिक
# tmp_suffix:न्त्रिक
# tmp_suffix:्त्रिक
# tmp_suffix:त्रिक
# tmp_suffix:्रिक
# tmp_suffix:रिक
# tmp_suffix:िक
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:104
#
# Suffix_del:िक
# िक .
#
# final stiped word: प्रजातान्त्र
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:्रजातान्त्र
# tmp_suffix:रजातान्त्र
# tmp_suffix:जातान्त्र
# tmp_suffix:ातान्त्र
# tmp_suffix:तान्त्र
# tmp_suffix:ान्त्र
# tmp_suffix:न्त्र
# tmp_suffix:्त्र
# tmp_suffix:त्र
# tmp_suffix:्र
# tmp_suffix:र
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:प
# tmp_prefix:प्
# tmp_prefix:प्र
# tmp_prefix:प्रज
# tmp_prefix:प्रजा
# tmp_prefix:प्रजात
# tmp_prefix:प्रजाता
# tmp_prefix:प्रजातान
# tmp_prefix:प्रजातान्
# tmp_prefix:प्रजातान्त
# tmp_prefix:प्रजातान्त्
# tmp_prefix:प्रजातान्त्र
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):प्रजातान्त्रिक
#
# Unstemmed input token38:लडाइँलाई
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:डाइँलाई
# tmp_suffix:ाइँलाई
# tmp_suffix:इँलाई
# tmp_suffix:ँलाई
# tmp_suffix:लाई
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:2
#
# Suffix_del:लाई
# लाई .
#
# final stiped word: लडाइँ
# Checking root word or not
# comdition1
#
# Root word found:लडाइँ
#
# final stemmed token:लडाइँ
#
# Unstemmed input token39:निरन्तरता
# Checking root word or not
# comdition1
#
# Root word found:निरन्तरता
#
# final stemmed token:निरन्तरता
#
# Unstemmed input token40:दिने
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:िने
# tmp_suffix:ने
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:16
#
# Suffix_del:ने
# ने .
#
# final stiped word: दि
# Checking root word or not
# comdition1
#
# Root word found:दि
#
# final stemmed token:दि
#
# Unstemmed input token41:क्रममा
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:्रममा
# tmp_suffix:रममा
# tmp_suffix:ममा
# tmp_suffix:मा
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:57
#
# Suffix_del:मा
# मा .
#
# final stiped word: क्रम
# Checking root word or not
# comdition1
#
# Root word found:क्रम
#
# final stemmed token:क्रम
#
# Unstemmed input token42:तपाईँ
# Checking root word or not
# comdition1
#
# Root word found:तपाईँ
#
# final stemmed token:तपाईँ
#
# Unstemmed input token43:हाम्रै
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ाम्रै
# tmp_suffix:म्रै
# tmp_suffix:्रै
# tmp_suffix:रै
# tmp_suffix:ै
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:83
#
# Suffix_del:ै
# ै ्
# not_dot ्
#
# final stiped word: हाम्र्
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ाम्र्
# tmp_suffix:म्र्
# tmp_suffix:्र्
# tmp_suffix:र्
# tmp_suffix:्
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:ह
# tmp_prefix:हा
# tmp_prefix:हाम
# tmp_prefix:हाम्
# tmp_prefix:हाम्र
# tmp_prefix:हाम्र्
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):हाम्रै
#
# Unstemmed input token44:गाउँघरमा
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ाउँघरमा
# tmp_suffix:उँघरमा
# tmp_suffix:ँघरमा
# tmp_suffix:घरमा
# tmp_suffix:रमा
# tmp_suffix:मा
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:57
#
# Suffix_del:मा
# मा .
#
# final stiped word: गाउँघर
# Checking root word or not
# comdition1
#
# Root word found:गाउँघर
#
# final stemmed token:गाउँघर
#
# Unstemmed input token45:कैयन्
# Checking root word or not
# comdition1
#
# Root word found:कैयन्
#
# final stemmed token:कैयन्
#
# Unstemmed input token46:घरबारहरू
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:रबारहरू
# tmp_suffix:बारहरू
# tmp_suffix:ारहरू
# tmp_suffix:रहरू
# tmp_suffix:हरू
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:1
#
# Suffix_del:हरू
# हरू .
#
# final stiped word: घरबार
# Checking root word or not
# comdition1
#
# Root word found:घरबार
#
# final stemmed token:घरबार
#
# Unstemmed input token47:राजनीतिक
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ाजनीतिक
# tmp_suffix:जनीतिक
# tmp_suffix:नीतिक
# tmp_suffix:ीतिक
# tmp_suffix:तिक
# tmp_suffix:िक
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:104
#
# Suffix_del:िक
# िक .
#
# final stiped word: राजनीत
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ाजनीत
# tmp_suffix:जनीत
# tmp_suffix:नीत
# tmp_suffix:ीत
# tmp_suffix:त
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:र
# tmp_prefix:रा
# tmp_prefix:राज
# tmp_prefix:राजन
# tmp_prefix:राजनी
# tmp_prefix:राजनीत
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):राजनीतिक
#
# Unstemmed input token48:कारणले
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ारणले
# tmp_suffix:रणले
# tmp_suffix:णले
# tmp_suffix:ले
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:3
#
# Suffix_del:ले
# ले .
#
# final stiped word: कारण
# Checking root word or not
# comdition1
#
# Root word found:कारण
#
# final stemmed token:कारण
#
# Unstemmed input token49:बेहाल
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ेहाल
# tmp_suffix:हाल
# tmp_suffix:ाल
# tmp_suffix:ल
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:ब
# tmp_prefix:बे
# tmp_prefix:बेह
# tmp_prefix:बेहा
# tmp_prefix:बेहाल
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):बेहाल
#
# Unstemmed input token50:बनाइएका
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:नाइएका
# tmp_suffix:ाइएका
# tmp_suffix:इएका
# tmp_suffix:एका
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:11
#
# Suffix_del:ाएका
#
# Suffix_del:ेका
#
# Suffix_del:एका
# एका .
#
# final stiped word: बनाइ
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:नाइ
# tmp_suffix:ाइ
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:63
#
# Suffix_del:आइ
#
# Suffix_del:ाइ
# ाइ ाउ
# not_dot ाउ
#
# final stiped word: बनाउ
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:नाउ
# tmp_suffix:ाउ
# tmp_suffix:उ
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:ब
# tmp_prefix:बन
# tmp_prefix:बना
# tmp_prefix:बनाउ
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):बनाइएका
#
# Unstemmed input token51:जनताको
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:नताको
# tmp_suffix:ताको
# tmp_suffix:ाको
# tmp_suffix:को
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:4
#
# Suffix_del:को
# को .
#
# final stiped word: जनता
# Checking root word or not
# comdition1
#
# Root word found:जनता
#
# final stemmed token:जनता
#
# Unstemmed input token52:अनवरत
# Checking root word or not
# comdition1
#
# Root word found:अनवरत
#
# final stemmed token:अनवरत
#
# Unstemmed input token53:सङ्घर्ष
# Checking root word or not
# comdition1
#
# Root word found:सङ्घर्ष
#
# final stemmed token:सङ्घर्ष
#
# Unstemmed input token54:खासगरी
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ासगरी
# tmp_suffix:सगरी
# tmp_suffix:गरी
# tmp_suffix:री
# tmp_suffix:ी
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:61
#
# Suffix_del:ी
# ी ्
# not_dot ्
#
# final stiped word: खासगर्
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ासगर्
# tmp_suffix:सगर्
# tmp_suffix:गर्
# tmp_suffix:र्
# tmp_suffix:्
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:ख
# tmp_prefix:खा
# tmp_prefix:खास
# tmp_prefix:खासग
# tmp_prefix:खासगर
# tmp_prefix:खासगर्
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):खासगरी
#
# Unstemmed input token55:अघिल्लो
# Checking root word or not
# comdition1
#
# Root word found:अघिल्लो
#
# final stemmed token:अघिल्लो
#
# Unstemmed input token56:वर्ष
# Checking root word or not
# comdition1
#
# Root word found:वर्ष
#
# final stemmed token:वर्ष
#
# Unstemmed input token57:राजनीतिक
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ाजनीतिक
# tmp_suffix:जनीतिक
# tmp_suffix:नीतिक
# tmp_suffix:ीतिक
# tmp_suffix:तिक
# tmp_suffix:िक
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:104
#
# Suffix_del:िक
# िक .
#
# final stiped word: राजनीत
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ाजनीत
# tmp_suffix:जनीत
# tmp_suffix:नीत
# tmp_suffix:ीत
# tmp_suffix:त
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:र
# tmp_prefix:रा
# tmp_prefix:राज
# tmp_prefix:राजन
# tmp_prefix:राजनी
# tmp_prefix:राजनीत
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):राजनीतिक
#
# Unstemmed input token58:विचारधारा
# Checking root word or not
# comdition1
#
# Root word found:विचारधारा
#
# final stemmed token:विचारधारा
#
# Unstemmed input token59:बर्ग
# Checking root word or not
# comdition1
#
# Root word found:बर्ग
#
# final stemmed token:बर्ग
#
# Unstemmed input token60:धर्म
# Checking root word or not
# comdition1
#
# Root word found:धर्म
#
# final stemmed token:धर्म
#
# Unstemmed input token61:पेसा
# Checking root word or not
# comdition1
#
# Root word found:पेसा
#
# final stemmed token:पेसा
#
# Unstemmed input token62:जात
# Checking root word or not
# comdition1
#
# Root word found:जात
#
# final stemmed token:जात
#
# Unstemmed input token63:जातिको
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ातिको
# tmp_suffix:तिको
# tmp_suffix:िको
# tmp_suffix:को
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:4
#
# Suffix_del:को
# को .
#
# final stiped word: जाति
# Checking root word or not
# comdition1
#
# Root word found:जाति
#
# final stemmed token:जाति
#
# Unstemmed input token64:भेदभाव
# Checking root word or not
# comdition1
#
# Root word found:भेदभाव
#
# final stemmed token:भेदभाव
#
# Unstemmed input token65:नराखी
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:राखी
# tmp_suffix:ाखी
# tmp_suffix:खी
# tmp_suffix:ी
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:61
#
# Suffix_del:ी
# ी ्
# not_dot ्
#
# final stiped word: नराख्
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:राख्
# tmp_suffix:ाख्
# tmp_suffix:ख्
# tmp_suffix:्
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:न
#
# prefix found
# comdition5
#
# Stripping prefix
# rule:1
#
# Prefix_del:न
#
# final stiped word: राख्
# Checking root word or not
# comdition1
#
# Root word found:राख्
#
# final stemmed token:राख्
#
# Unstemmed input token66:ढिको
# Checking root word or not
# comdition1
#
# Root word found:ढिको
#
# final stemmed token:ढिको
#
# Unstemmed input token67:ढिकको
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:िकको
# tmp_suffix:कको
# tmp_suffix:को
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:4
#
# Suffix_del:को
# को .
#
# final stiped word: ढिक
# Checking root word or not
# comdition1
#
# Root word found:ढिक
#
# final stemmed token:ढिक
#
# Unstemmed input token68:नेपाली
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ेपाली
# tmp_suffix:पाली
# tmp_suffix:ाली
# tmp_suffix:ली
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:49
#
# Suffix_del:ली
# ली .
#
# final stiped word: नेपा
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ेपा
# tmp_suffix:पा
# tmp_suffix:ा
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:10
#
# Suffix_del:ा
# ा ्
# not_dot ्
#
# final stiped word: नेप्
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ेप्
# tmp_suffix:प्
# tmp_suffix:्
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:न
#
# prefix found
# comdition5
#
# Stripping prefix
# rule:1
#
# Prefix_del:न
#
# final stiped word: ेप्
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:प्
# tmp_suffix:्
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:े
# tmp_prefix:ेप
# tmp_prefix:ेप्
#
# prefix not found
#
# Recombining suffix
# comdition6:bot suffix and prefix found previously
# PMorph:['', 'न', 'न', '', '', '', '', '', '', '']
#
# generating word
# generated word: ेपा
#
# generating word
# generated word: ेपाली
#
# final token (couldnt stem):नेपाली
#
# Unstemmed input token69:जनताको
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:नताको
# tmp_suffix:ताको
# tmp_suffix:ाको
# tmp_suffix:को
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:4
#
# Suffix_del:को
# को .
#
# final stiped word: जनता
# Checking root word or not
# comdition1
#
# Root word found:जनता
#
# final stemmed token:जनता
#
# Unstemmed input token70:जुझारू
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ुझारू
# tmp_suffix:झारू
# tmp_suffix:ारू
# tmp_suffix:रू
# tmp_suffix:ू
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:ज
# tmp_prefix:जु
# tmp_prefix:जुझ
# tmp_prefix:जुझा
# tmp_prefix:जुझार
# tmp_prefix:जुझारू
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):जुझारू
#
# Unstemmed input token71:निर्णायक
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:िर्णायक
# tmp_suffix:र्णायक
# tmp_suffix:्णायक
# tmp_suffix:णायक
# tmp_suffix:ायक
# tmp_suffix:यक
# tmp_suffix:क
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:न
#
# prefix found
# comdition5
#
# Stripping prefix
# rule:1
#
# Prefix_del:न
#
# final stiped word: िर्णायक
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:र्णायक
# tmp_suffix:्णायक
# tmp_suffix:णायक
# tmp_suffix:ायक
# tmp_suffix:यक
# tmp_suffix:क
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:ि
# tmp_prefix:िर
# tmp_prefix:िर्
# tmp_prefix:िर्ण
# tmp_prefix:िर्णा
# tmp_prefix:िर्णाय
# tmp_prefix:िर्णायक
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):निर्णायक
#
# Unstemmed input token72:सङ्घर्षले
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ङ्घर्षले
# tmp_suffix:्घर्षले
# tmp_suffix:घर्षले
# tmp_suffix:र्षले
# tmp_suffix:्षले
# tmp_suffix:षले
# tmp_suffix:ले
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:3
#
# Suffix_del:ले
# ले .
#
# final stiped word: सङ्घर्ष
# Checking root word or not
# comdition1
#
# Root word found:सङ्घर्ष
#
# final stemmed token:सङ्घर्ष
#
# Unstemmed input token73:वर्षसम्म
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:र्षसम्म
# tmp_suffix:्षसम्म
# tmp_suffix:षसम्म
# tmp_suffix:सम्म
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:87
#
# Suffix_del:सम्म
# सम्म .
#
# final stiped word: वर्ष
# Checking root word or not
# comdition1
#
# Root word found:वर्ष
#
# final stemmed token:वर्ष
#
# Unstemmed input token74:एकछत्र
# Checking root word or not
# comdition1
#
# Root word found:एकछत्र
#
# final stemmed token:एकछत्र
#
# Unstemmed input token75:रजाइँ
# Checking root word or not
# comdition1
#
# Root word found:रजाइँ
#
# final stemmed token:रजाइँ
#
# Unstemmed input token76:दलीय
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:लीय
# tmp_suffix:ीय
# tmp_suffix:य
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:द
# tmp_prefix:दल
# tmp_prefix:दली
# tmp_prefix:दलीय
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):दलीय
#
# Unstemmed input token77:तानाशाही
# Checking root word or not
# comdition1
#
# Root word found:तानाशाही
#
# final stemmed token:तानाशाही
#
# Unstemmed input token78:व्यवस्थालाई
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:्यवस्थालाई
# tmp_suffix:यवस्थालाई
# tmp_suffix:वस्थालाई
# tmp_suffix:स्थालाई
# tmp_suffix:्थालाई
# tmp_suffix:थालाई
# tmp_suffix:ालाई
# tmp_suffix:लाई
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:2
#
# Suffix_del:लाई
# लाई .
#
# final stiped word: व्यवस्था
# Checking root word or not
# comdition1
#
# Root word found:व्यवस्था
#
# final stemmed token:व्यवस्था
#
# Unstemmed input token79:लत्‌र्याइयो
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:त्‌र्याइयो
# tmp_suffix:्‌र्याइयो
# tmp_suffix:‌र्याइयो
# tmp_suffix:र्याइयो
# tmp_suffix:्याइयो
# tmp_suffix:याइयो
# tmp_suffix:ाइयो
# tmp_suffix:इयो
# tmp_suffix:यो
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:17
#
# Suffix_del:यो
# यो .
#
# final stiped word: लत्‌र्याइ
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:त्‌र्याइ
# tmp_suffix:्‌र्याइ
# tmp_suffix:‌र्याइ
# tmp_suffix:र्याइ
# tmp_suffix:्याइ
# tmp_suffix:याइ
# tmp_suffix:ाइ
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:63
#
# Suffix_del:आइ
#
# Suffix_del:ाइ
# ाइ ाउ
# not_dot ाउ
#
# final stiped word: लत्‌र्याउ
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:त्‌र्याउ
# tmp_suffix:्‌र्याउ
# tmp_suffix:‌र्याउ
# tmp_suffix:र्याउ
# tmp_suffix:्याउ
# tmp_suffix:याउ
# tmp_suffix:ाउ
# tmp_suffix:उ
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:ल
# tmp_prefix:लत
# tmp_prefix:लत्
# tmp_prefix:लत्‌
# tmp_prefix:लत्‌र
# tmp_prefix:लत्‌र्
# tmp_prefix:लत्‌र्य
# tmp_prefix:लत्‌र्या
# tmp_prefix:लत्‌र्याउ
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):लत्‌र्याइयो
#
# Unstemmed input token80:अथाह
# Checking root word or not
# comdition1
#
# Root word found:अथाह
#
# final stemmed token:अथाह
#
# Unstemmed input token81:कष्ट
# Checking root word or not
# comdition1
#
# Root word found:कष्ट
#
# final stemmed token:कष्ट
#
# Unstemmed input token82:असह्य
# Checking root word or not
# comdition1
#
# Root word found:असह्य
#
# final stemmed token:असह्य
#
# Unstemmed input token83:यातना
# Checking root word or not
# comdition1
#
# Root word found:यातना
#
# final stemmed token:यातना
#
# Unstemmed input token84:निर्मम
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:िर्मम
# tmp_suffix:र्मम
# tmp_suffix:्मम
# tmp_suffix:मम
# tmp_suffix:म
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:न
#
# prefix found
# comdition5
#
# Stripping prefix
# rule:1
#
# Prefix_del:न
#
# final stiped word: िर्मम
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:र्मम
# tmp_suffix:्मम
# tmp_suffix:मम
# tmp_suffix:म
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:ि
# tmp_prefix:िर
# tmp_prefix:िर्
# tmp_prefix:िर्म
# tmp_prefix:िर्मम
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):निर्मम
#
# Unstemmed input token85:शोषणमाथि
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ोषणमाथि
# tmp_suffix:षणमाथि
# tmp_suffix:णमाथि
# tmp_suffix:माथि
# tmp_suffix:ाथि
# tmp_suffix:थि
# tmp_suffix:ि
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:63
#
# Suffix_del:आइ
#
# Suffix_del:ाइ
#
# Suffix_del:ि
# ि ्
# not_dot ्
#
# final stiped word: शोषणमाथ्
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ोषणमाथ्
# tmp_suffix:षणमाथ्
# tmp_suffix:णमाथ्
# tmp_suffix:माथ्
# tmp_suffix:ाथ्
# tmp_suffix:थ्
# tmp_suffix:्
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:श
# tmp_prefix:शो
# tmp_prefix:शोष
# tmp_prefix:शोषण
# tmp_prefix:शोषणम
# tmp_prefix:शोषणमा
# tmp_prefix:शोषणमाथ
# tmp_prefix:शोषणमाथ्
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):शोषणमाथि
#
# Unstemmed input token86:बनेको
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:नेको
# tmp_suffix:ेको
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:89
#
# Suffix_del:ाएको
#
# Suffix_del:ेको
# ेको ्
# not_dot ्
#
# final stiped word: बन्
# Checking root word or not
# comdition1
#
# Root word found:बन्
#
# final stemmed token:बन्
#
# Unstemmed input token87:निरङ्कुशताको
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:िरङ्कुशताको
# tmp_suffix:रङ्कुशताको
# tmp_suffix:ङ्कुशताको
# tmp_suffix:्कुशताको
# tmp_suffix:कुशताको
# tmp_suffix:ुशताको
# tmp_suffix:शताको
# tmp_suffix:ताको
# tmp_suffix:ाको
# tmp_suffix:को
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:4
#
# Suffix_del:को
# को .
#
# final stiped word: निरङ्कुशता
# Checking root word or not
# comdition1
#
# Root word found:निरङ्कुशता
#
# final stemmed token:निरङ्कुशता
#
# Unstemmed input token88:महल
# Checking root word or not
# comdition1
#
# Root word found:महल
#
# final stemmed token:महल
#
# Unstemmed input token89:रहेन
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:हेन
# tmp_suffix:ेन
# tmp_suffix:न
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:12
#
# Suffix_del:न
# न .
#
# final stiped word: रहे
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:हे
# tmp_suffix:े
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:23
#
# Suffix_del:एँ
#
# Suffix_del:ए
#
# Suffix_del:ेँ
#
# Suffix_del:े
# े ्
# not_dot ्
#
# final stiped word: रह्
# Checking root word or not
# comdition1
#
# Root word found:रह्
#
# final stemmed token:रह्
#
# Unstemmed input token90:वर्षपछि
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:र्षपछि
# tmp_suffix:्षपछि
# tmp_suffix:षपछि
# tmp_suffix:पछि
# tmp_suffix:छि
# tmp_suffix:ि
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:63
#
# Suffix_del:आइ
#
# Suffix_del:ाइ
#
# Suffix_del:ि
# ि ्
# not_dot ्
#
# final stiped word: वर्षपछ्
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:र्षपछ्
# tmp_suffix:्षपछ्
# tmp_suffix:षपछ्
# tmp_suffix:पछ्
# tmp_suffix:छ्
# tmp_suffix:्
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:व
# tmp_prefix:वर
# tmp_prefix:वर्
# tmp_prefix:वर्ष
# tmp_prefix:वर्षप
# tmp_prefix:वर्षपछ
# tmp_prefix:वर्षपछ्
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):वर्षपछि
#
# Unstemmed input token91:नेपाली
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ेपाली
# tmp_suffix:पाली
# tmp_suffix:ाली
# tmp_suffix:ली
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:49
#
# Suffix_del:ली
# ली .
#
# final stiped word: नेपा
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ेपा
# tmp_suffix:पा
# tmp_suffix:ा
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:10
#
# Suffix_del:ा
# ा ्
# not_dot ्
#
# final stiped word: नेप्
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ेप्
# tmp_suffix:प्
# tmp_suffix:्
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:न
#
# prefix found
# comdition5
#
# Stripping prefix
# rule:1
#
# Prefix_del:न
#
# final stiped word: ेप्
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:प्
# tmp_suffix:्
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:े
# tmp_prefix:ेप
# tmp_prefix:ेप्
#
# prefix not found
#
# Recombining suffix
# comdition6:bot suffix and prefix found previously
# PMorph:['', 'न', 'न', '', '', '', '', '', '', '']
#
# generating word
# generated word: ेपा
#
# generating word
# generated word: ेपाली
#
# final token (couldnt stem):नेपाली
#
# Unstemmed input token92:जनता
# Checking root word or not
# comdition1
#
# Root word found:जनता
#
# final stemmed token:जनता
#
# Unstemmed input token93:बहुदलीय
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:हुदलीय
# tmp_suffix:ुदलीय
# tmp_suffix:दलीय
# tmp_suffix:लीय
# tmp_suffix:ीय
# tmp_suffix:य
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:ब
# tmp_prefix:बह
# tmp_prefix:बहु
# tmp_prefix:बहुद
# tmp_prefix:बहुदल
# tmp_prefix:बहुदली
# tmp_prefix:बहुदलीय
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):बहुदलीय
#
# Unstemmed input token94:प्रतिस्पर्धात्मक
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:्रतिस्पर्धात्मक
# tmp_suffix:रतिस्पर्धात्मक
# tmp_suffix:तिस्पर्धात्मक
# tmp_suffix:िस्पर्धात्मक
# tmp_suffix:स्पर्धात्मक
# tmp_suffix:्पर्धात्मक
# tmp_suffix:पर्धात्मक
# tmp_suffix:र्धात्मक
# tmp_suffix:्धात्मक
# tmp_suffix:धात्मक
# tmp_suffix:ात्मक
# tmp_suffix:त्मक
# tmp_suffix:्मक
# tmp_suffix:मक
# tmp_suffix:क
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:प
# tmp_prefix:प्
# tmp_prefix:प्र
# tmp_prefix:प्रत
# tmp_prefix:प्रति
# tmp_prefix:प्रतिस
# tmp_prefix:प्रतिस्
# tmp_prefix:प्रतिस्प
# tmp_prefix:प्रतिस्पर
# tmp_prefix:प्रतिस्पर्
# tmp_prefix:प्रतिस्पर्ध
# tmp_prefix:प्रतिस्पर्धा
# tmp_prefix:प्रतिस्पर्धात
# tmp_prefix:प्रतिस्पर्धात्
# tmp_prefix:प्रतिस्पर्धात्म
# tmp_prefix:प्रतिस्पर्धात्मक
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):प्रतिस्पर्धात्मक
#
# Unstemmed input token95:वातावरणमा
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ातावरणमा
# tmp_suffix:तावरणमा
# tmp_suffix:ावरणमा
# tmp_suffix:वरणमा
# tmp_suffix:रणमा
# tmp_suffix:णमा
# tmp_suffix:मा
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:57
#
# Suffix_del:मा
# मा .
#
# final stiped word: वातावरण
# Checking root word or not
# comdition1
#
# Root word found:वातावरण
#
# final stemmed token:वातावरण
#
# Unstemmed input token96:आम
# Checking root word or not
# comdition1
#
# Root word found:आम
#
# final stemmed token:आम
#
# Unstemmed input token97:चुनावमा
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ुनावमा
# tmp_suffix:नावमा
# tmp_suffix:ावमा
# tmp_suffix:वमा
# tmp_suffix:मा
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:57
#
# Suffix_del:मा
# मा .
#
# final stiped word: चुनाव
# Checking root word or not
# comdition1
#
# Root word found:चुनाव
#
# final stemmed token:चुनाव
#
# Unstemmed input token98:पाइ
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ाइ
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:63
#
# Suffix_del:आइ
#
# Suffix_del:ाइ
# ाइ ाउ
# not_dot ाउ
#
# final stiped word: पाउ
# Checking root word or not
# comdition1
#
# Root word found:पाउ
#
# final stemmed token:पाउ
#
# Unstemmed input token99:सुखद
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ुखद
# tmp_suffix:खद
# tmp_suffix:द
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:स
# tmp_prefix:सु
#
# prefix found
# comdition5
#
# Stripping prefix
# rule:5
#
# Prefix_del:सु
# final stiped word: खद
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:द
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:ख
# tmp_prefix:खद
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):सुखद
#
# Unstemmed input token100:अवसरमा
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:वसरमा
# tmp_suffix:सरमा
# tmp_suffix:रमा
# tmp_suffix:मा
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:57
#
# Suffix_del:मा
# मा .
#
# final stiped word: अवसर
# Checking root word or not
# comdition1
#
# Root word found:अवसर
#
# final stemmed token:अवसर
#
# Unstemmed input token101:प्रजातान्त्रिक
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:्रजातान्त्रिक
# tmp_suffix:रजातान्त्रिक
# tmp_suffix:जातान्त्रिक
# tmp_suffix:ातान्त्रिक
# tmp_suffix:तान्त्रिक
# tmp_suffix:ान्त्रिक
# tmp_suffix:न्त्रिक
# tmp_suffix:्त्रिक
# tmp_suffix:त्रिक
# tmp_suffix:्रिक
# tmp_suffix:रिक
# tmp_suffix:िक
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:104
#
# Suffix_del:िक
# िक .
#
# final stiped word: प्रजातान्त्र
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:्रजातान्त्र
# tmp_suffix:रजातान्त्र
# tmp_suffix:जातान्त्र
# tmp_suffix:ातान्त्र
# tmp_suffix:तान्त्र
# tmp_suffix:ान्त्र
# tmp_suffix:न्त्र
# tmp_suffix:्त्र
# tmp_suffix:त्र
# tmp_suffix:्र
# tmp_suffix:र
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:प
# tmp_prefix:प्
# tmp_prefix:प्र
# tmp_prefix:प्रज
# tmp_prefix:प्रजा
# tmp_prefix:प्रजात
# tmp_prefix:प्रजाता
# tmp_prefix:प्रजातान
# tmp_prefix:प्रजातान्
# tmp_prefix:प्रजातान्त
# tmp_prefix:प्रजातान्त्
# tmp_prefix:प्रजातान्त्र
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):प्रजातान्त्रिक
#
# Unstemmed input token102:जनमञ्च
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:नमञ्च
# tmp_suffix:मञ्च
# tmp_suffix:ञ्च
# tmp_suffix:्च
# tmp_suffix:च
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:ज
# tmp_prefix:जन
# tmp_prefix:जनम
# tmp_prefix:जनमञ
# tmp_prefix:जनमञ्
# tmp_prefix:जनमञ्च
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):जनमञ्च
#
# Unstemmed input token103:निरङ्कुशता
# Checking root word or not
# comdition1
#
# Root word found:निरङ्कुशता
#
# final stemmed token:निरङ्कुशता
#
# Unstemmed input token104:फाल्न
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ाल्न
# tmp_suffix:ल्न
# tmp_suffix:्न
# tmp_suffix:न
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:12
#
# Suffix_del:न
# न .
#
# final stiped word: फाल्
# Checking root word or not
# comdition1
#
# Root word found:फाल्
#
# final stemmed token:फाल्
#
# Unstemmed input token105:प्रजातन्त्र
# Checking root word or not
# comdition1
#
# Root word found:प्रजातन्त्र
#
# final stemmed token:प्रजातन्त्र
#
# Unstemmed input token106:ल्याउन
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:्याउन
# tmp_suffix:याउन
# tmp_suffix:ाउन
# tmp_suffix:उन
# tmp_suffix:न
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:12
#
# Suffix_del:न
# न .
#
# final stiped word: ल्याउ
# Checking root word or not
# comdition1
#
# Root word found:ल्याउ
#
# final stemmed token:ल्याउ
#
# Unstemmed input token107:सहादत
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:हादत
# tmp_suffix:ादत
# tmp_suffix:दत
# tmp_suffix:त
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:स
# tmp_prefix:सह
# tmp_prefix:सहा
# tmp_prefix:सहाद
# tmp_prefix:सहादत
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):सहादत
#
# Unstemmed input token108:हुनुहुने
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ुनुहुने
# tmp_suffix:नुहुने
# tmp_suffix:ुहुने
# tmp_suffix:हुने
# tmp_suffix:ुने
# tmp_suffix:ने
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:16
#
# Suffix_del:ने
# ने .
#
# final stiped word: हुनुहु
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ुनुहु
# tmp_suffix:नुहु
# tmp_suffix:ुहु
# tmp_suffix:हु
# tmp_suffix:ु
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:ह
# tmp_prefix:हु
# tmp_prefix:हुन
# tmp_prefix:हुनु
# tmp_prefix:हुनुह
# tmp_prefix:हुनुहु
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):हुनुहुने
#
# Unstemmed input token109:तमाम
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:माम
# tmp_suffix:ाम
# tmp_suffix:म
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:त
# tmp_prefix:तम
# tmp_prefix:तमा
# tmp_prefix:तमाम
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):तमाम
#
# Unstemmed input token110:शहीदहरूमा
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:हीदहरूमा
# tmp_suffix:ीदहरूमा
# tmp_suffix:दहरूमा
# tmp_suffix:हरूमा
# tmp_suffix:रूमा
# tmp_suffix:ूमा
# tmp_suffix:मा
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:57
#
# Suffix_del:मा
# मा .
#
# final stiped word: शहीदहरू
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:हीदहरू
# tmp_suffix:ीदहरू
# tmp_suffix:दहरू
# tmp_suffix:हरू
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:1
#
# Suffix_del:हरू
# हरू .
#
# final stiped word: शहीद
# Checking root word or not
# comdition1
#
# Root word found:शहीद
#
# final stemmed token:शहीद
#
# Unstemmed input token111:कृतज्ञता
# Checking root word or not
# comdition1
#
# Root word found:कृतज्ञता
#
# final stemmed token:कृतज्ञता
#
# Unstemmed input token112:पूर्वक
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ूर्वक
# tmp_suffix:र्वक
# tmp_suffix:्वक
# tmp_suffix:वक
# tmp_suffix:क
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:प
# tmp_prefix:पू
# tmp_prefix:पूर
# tmp_prefix:पूर्
# tmp_prefix:पूर्व
# tmp_prefix:पूर्वक
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):पूर्वक
#
# Unstemmed input token113:श्रद्धाञ्जली
# Checking root word or not
# comdition1
#
# Root word found:श्रद्धाञ्जली
#
# final stemmed token:श्रद्धाञ्जली
#
# Unstemmed input token114:अर्पण
# Checking root word or not
# comdition1
#
# Root word found:अर्पण
#
# final stemmed token:अर्पण
#
# Unstemmed input token115:विजयमा
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:िजयमा
# tmp_suffix:जयमा
# tmp_suffix:यमा
# tmp_suffix:मा
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:57
#
# Suffix_del:मा
# मा .
#
# final stiped word: विजय
# Checking root word or not
# comdition1
#
# Root word found:विजय
#
# final stemmed token:विजय
#
# Unstemmed input token116:नेपाली
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ेपाली
# tmp_suffix:पाली
# tmp_suffix:ाली
# tmp_suffix:ली
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:49
#
# Suffix_del:ली
# ली .
#
# final stiped word: नेपा
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ेपा
# tmp_suffix:पा
# tmp_suffix:ा
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:10
#
# Suffix_del:ा
# ा ्
# not_dot ्
#
# final stiped word: नेप्
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ेप्
# tmp_suffix:प्
# tmp_suffix:्
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:न
#
# prefix found
# comdition5
#
# Stripping prefix
# rule:1
#
# Prefix_del:न
#
# final stiped word: ेप्
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:प्
# tmp_suffix:्
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:े
# tmp_prefix:ेप
# tmp_prefix:ेप्
#
# prefix not found
#
# Recombining suffix
# comdition6:bot suffix and prefix found previously
# PMorph:['', 'न', 'न', '', '', '', '', '', '', '']
#
# generating word
# generated word: ेपा
#
# generating word
# generated word: ेपाली
#
# final token (couldnt stem):नेपाली
#
# Unstemmed input token117:जनताको
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:नताको
# tmp_suffix:ताको
# tmp_suffix:ाको
# tmp_suffix:को
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:4
#
# Suffix_del:को
# को .
#
# final stiped word: जनता
# Checking root word or not
# comdition1
#
# Root word found:जनता
#
# final stemmed token:जनता
#
# Unstemmed input token118:अजेय
# Checking root word or not
# comdition1
#
# Root word found:अजेय
#
# final stemmed token:अजेय
#
# Unstemmed input token119:पौरख
# Checking root word or not
# comdition1
#
# Root word found:पौरख
#
# final stemmed token:पौरख
#
# Unstemmed input token120:अभिव्यक्त
# Checking root word or not
# comdition1
#
# Root word found:अभिव्यक्त
#
# final stemmed token:अभिव्यक्त
#
# Unstemmed input token121:समस्त
# Checking root word or not
# comdition1
#
# Root word found:समस्त
#
# final stemmed token:समस्त
#
# Unstemmed input token122:नेपाली
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ेपाली
# tmp_suffix:पाली
# tmp_suffix:ाली
# tmp_suffix:ली
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:49
#
# Suffix_del:ली
# ली .
#
# final stiped word: नेपा
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ेपा
# tmp_suffix:पा
# tmp_suffix:ा
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:10
#
# Suffix_del:ा
# ा ्
# not_dot ्
#
# final stiped word: नेप्
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ेप्
# ...
# comdition1
#
# Root word found:स्वायत्त
#
# final stemmed token:स्वायत्त
#
# Unstemmed input token1361:क्षेत्र
# Checking root word or not
# comdition1
#
# Root word found:क्षेत्र
#
# final stemmed token:क्षेत्र
#
# Unstemmed input token1362:परेका
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:रेका
# tmp_suffix:ेका
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:11
#
# Suffix_del:ाएका
#
# Suffix_del:ेका
# ेका ्
# not_dot ्
#
# final stiped word: पर्
# Checking root word or not
# comdition1
#
# Root word found:पर्
#
# final stemmed token:पर्
#
# Unstemmed input token1363:जात
# Checking root word or not
# comdition1
#
# Root word found:जात
#
# final stemmed token:जात
#
# Unstemmed input token1364:जनजातिहरूको
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:नजातिहरूको
# tmp_suffix:जातिहरूको
# tmp_suffix:ातिहरूको
# tmp_suffix:तिहरूको
# tmp_suffix:िहरूको
# tmp_suffix:हरूको
# tmp_suffix:रूको
# tmp_suffix:ूको
# tmp_suffix:को
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:4
#
# Suffix_del:को
# को .
#
# final stiped word: जनजातिहरू
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:नजातिहरू
# tmp_suffix:जातिहरू
# tmp_suffix:ातिहरू
# tmp_suffix:तिहरू
# tmp_suffix:िहरू
# tmp_suffix:हरू
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:1
#
# Suffix_del:हरू
# हरू .
#
# final stiped word: जनजाति
# Checking root word or not
# comdition1
#
# Root word found:जनजाति
#
# final stemmed token:जनजाति
#
# Unstemmed input token1365:आरक्षण
# Checking root word or not
# comdition1
#
# Root word found:आरक्षण
#
# final stemmed token:आरक्षण
#
# Unstemmed input token1366:जातीय
# Checking root word or not
# comdition1
#
# Root word found:जातीय
#
# final stemmed token:जातीय
#
# Unstemmed input token1367:समानुपातिक
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:मानुपातिक
# tmp_suffix:ानुपातिक
# tmp_suffix:नुपातिक
# tmp_suffix:ुपातिक
# tmp_suffix:पातिक
# tmp_suffix:ातिक
# tmp_suffix:तिक
# tmp_suffix:िक
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:104
#
# Suffix_del:िक
# िक .
#
# final stiped word: समानुपात
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:मानुपात
# tmp_suffix:ानुपात
# tmp_suffix:नुपात
# tmp_suffix:ुपात
# tmp_suffix:पात
# tmp_suffix:ात
# tmp_suffix:त
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:स
# tmp_prefix:सम
# tmp_prefix:समा
# tmp_prefix:समान
# tmp_prefix:समानु
# tmp_prefix:समानुप
# tmp_prefix:समानुपा
# tmp_prefix:समानुपात
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):समानुपातिक
#
# Unstemmed input token1368:प्रतिनिधित्व
# Checking root word or not
# comdition1
#
# Root word found:प्रतिनिधित्व
#
# final stemmed token:प्रतिनिधित्व
#
# Unstemmed input token1369:सारिएका
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ारिएका
# tmp_suffix:रिएका
# tmp_suffix:िएका
# tmp_suffix:एका
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:11
#
# Suffix_del:ाएका
#
# Suffix_del:ेका
#
# Suffix_del:एका
# एका .
#
# final stiped word: सारि
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ारि
# tmp_suffix:रि
# tmp_suffix:ि
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:63
#
# Suffix_del:आइ
#
# Suffix_del:ाइ
#
# Suffix_del:ि
# ि ्
# not_dot ्
#
# final stiped word: सार्
# Checking root word or not
# comdition1
#
# Root word found:सार्
#
# final stemmed token:सार्
#
# Unstemmed input token1370:जातीय
# Checking root word or not
# comdition1
#
# Root word found:जातीय
#
# final stemmed token:जातीय
#
# Unstemmed input token1371:भेदभाव
# Checking root word or not
# comdition1
#
# Root word found:भेदभाव
#
# final stemmed token:भेदभाव
#
# Unstemmed input token1372:पछौटेपनको
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:छौटेपनको
# tmp_suffix:ौटेपनको
# tmp_suffix:टेपनको
# tmp_suffix:ेपनको
# tmp_suffix:पनको
# tmp_suffix:नको
# tmp_suffix:को
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:4
#
# Suffix_del:को
# को .
#
# final stiped word: पछौटेपन
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:छौटेपन
# tmp_suffix:ौटेपन
# tmp_suffix:टेपन
# tmp_suffix:ेपन
# tmp_suffix:पन
# tmp_suffix:न
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:12
#
# Suffix_del:न
# न .
#
# final stiped word: पछौटेप
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:छौटेप
# tmp_suffix:ौटेप
# tmp_suffix:टेप
# tmp_suffix:ेप
# tmp_suffix:प
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:प
# tmp_prefix:पछ
# tmp_prefix:पछौ
# tmp_prefix:पछौट
# tmp_prefix:पछौटे
# tmp_prefix:पछौटेप
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):पछौटेपनको
#
# Unstemmed input token1373:समाधान
# Checking root word or not
# comdition1
#
# Root word found:समाधान
#
# final stemmed token:समाधान
#
# Unstemmed input token1374:प्रजातान्त्रिक
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:्रजातान्त्रिक
# tmp_suffix:रजातान्त्रिक
# tmp_suffix:जातान्त्रिक
# tmp_suffix:ातान्त्रिक
# tmp_suffix:तान्त्रिक
# tmp_suffix:ान्त्रिक
# tmp_suffix:न्त्रिक
# tmp_suffix:्त्रिक
# tmp_suffix:त्रिक
# tmp_suffix:्रिक
# tmp_suffix:रिक
# tmp_suffix:िक
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:104
#
# Suffix_del:िक
# िक .
#
# final stiped word: प्रजातान्त्र
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:्रजातान्त्र
# tmp_suffix:रजातान्त्र
# tmp_suffix:जातान्त्र
# tmp_suffix:ातान्त्र
# tmp_suffix:तान्त्र
# tmp_suffix:ान्त्र
# tmp_suffix:न्त्र
# tmp_suffix:्त्र
# tmp_suffix:त्र
# tmp_suffix:्र
# tmp_suffix:र
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:प
# tmp_prefix:प्
# tmp_prefix:प्र
# tmp_prefix:प्रज
# tmp_prefix:प्रजा
# tmp_prefix:प्रजात
# tmp_prefix:प्रजाता
# tmp_prefix:प्रजातान
# tmp_prefix:प्रजातान्
# tmp_prefix:प्रजातान्त
# tmp_prefix:प्रजातान्त्
# tmp_prefix:प्रजातान्त्र
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):प्रजातान्त्रिक
#
# Unstemmed input token1375:प्रक्रियाबाट
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:्रक्रियाबाट
# tmp_suffix:रक्रियाबाट
# tmp_suffix:क्रियाबाट
# tmp_suffix:्रियाबाट
# tmp_suffix:रियाबाट
# tmp_suffix:ियाबाट
# tmp_suffix:याबाट
# tmp_suffix:ाबाट
# tmp_suffix:बाट
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:9
#
# Suffix_del:बाट
# बाट .
#
# final stiped word: प्रक्रिया
# Checking root word or not
# comdition1
#
# Root word found:प्रक्रिया
#
# final stemmed token:प्रक्रिया
#
# Unstemmed input token1376:गरिनु
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:रिनु
# tmp_suffix:िनु
# tmp_suffix:नु
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:22
#
# Suffix_del:नु
# नु .
#
# final stiped word: गरि
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:रि
# tmp_suffix:ि
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:63
#
# Suffix_del:आइ
#
# Suffix_del:ाइ
#
# Suffix_del:ि
# ि ्
# not_dot ्
#
# final stiped word: गर्
# Checking root word or not
# comdition1
#
# Root word found:गर्
#
# final stemmed token:गर्
#
# Unstemmed input token1377:पर्दछ
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:र्दछ
# tmp_suffix:्दछ
# tmp_suffix:दछ
# tmp_suffix:छ
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:7
#
# Suffix_del:ँछ
#
# Suffix_del:छ
# छ .
#
# final stiped word: पर्द
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:र्द
# tmp_suffix:्द
# tmp_suffix:द
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:प
# tmp_prefix:पर
# tmp_prefix:पर्
# tmp_prefix:पर्द
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):पर्दछ
#
# Unstemmed input token1378:यथार्थभित्र
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:थार्थभित्र
# tmp_suffix:ार्थभित्र
# tmp_suffix:र्थभित्र
# tmp_suffix:्थभित्र
# tmp_suffix:थभित्र
# tmp_suffix:भित्र
# tmp_suffix:ित्र
# tmp_suffix:त्र
# tmp_suffix:्र
# tmp_suffix:र
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:य
# tmp_prefix:यथ
# tmp_prefix:यथा
# tmp_prefix:यथार
# tmp_prefix:यथार्
# tmp_prefix:यथार्थ
# tmp_prefix:यथार्थभ
# tmp_prefix:यथार्थभि
# tmp_prefix:यथार्थभित
# tmp_prefix:यथार्थभित्
# tmp_prefix:यथार्थभित्र
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):यथार्थभित्र
#
# Unstemmed input token1379:राष्ट्रिय
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ाष्ट्रिय
# tmp_suffix:ष्ट्रिय
# tmp_suffix:्ट्रिय
# tmp_suffix:ट्रिय
# tmp_suffix:्रिय
# tmp_suffix:रिय
# tmp_suffix:िय
# tmp_suffix:य
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:र
# tmp_prefix:रा
# tmp_prefix:राष
# tmp_prefix:राष्
# tmp_prefix:राष्ट
# tmp_prefix:राष्ट्
# tmp_prefix:राष्ट्र
# tmp_prefix:राष्ट्रि
# tmp_prefix:राष्ट्रिय
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):राष्ट्रिय
#
# Unstemmed input token1380:छलफल
# Checking root word or not
# comdition1
#
# Root word found:छलफल
#
# final stemmed token:छलफल
#
# Unstemmed input token1381:राष्ट्रिय
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ाष्ट्रिय
# tmp_suffix:ष्ट्रिय
# tmp_suffix:्ट्रिय
# tmp_suffix:ट्रिय
# tmp_suffix:्रिय
# tmp_suffix:रिय
# tmp_suffix:िय
# tmp_suffix:य
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:र
# tmp_prefix:रा
# tmp_prefix:राष
# tmp_prefix:राष्
# tmp_prefix:राष्ट
# tmp_prefix:राष्ट्
# tmp_prefix:राष्ट्र
# tmp_prefix:राष्ट्रि
# tmp_prefix:राष्ट्रिय
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):राष्ट्रिय
#
# Unstemmed input token1382:सहमति
# Checking root word or not
# comdition1
#
# Root word found:सहमति
#
# final stemmed token:सहमति
#
# Unstemmed input token1383:निकाल्नु
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:िकाल्नु
# tmp_suffix:काल्नु
# tmp_suffix:ाल्नु
# tmp_suffix:ल्नु
# tmp_suffix:्नु
# tmp_suffix:नु
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:22
#
# Suffix_del:नु
# नु .
#
# final stiped word: निकाल्
# Checking root word or not
# comdition1
#
# Root word found:निकाल्
#
# final stemmed token:निकाल्
#
# Unstemmed input token1384:आवश्यक
# Checking root word or not
# comdition1
#
# Root word found:आवश्यक
#
# final stemmed token:आवश्यक
#
# Unstemmed input token1385:जातीय
# Checking root word or not
# comdition1
#
# Root word found:जातीय
#
# final stemmed token:जातीय
#
# Unstemmed input token1386:समस्या
# Checking root word or not
# comdition1
#
# Root word found:समस्या
#
# final stemmed token:समस्या
#
# Unstemmed input token1387:प्रतिगामी
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:्रतिगामी
# tmp_suffix:रतिगामी
# tmp_suffix:तिगामी
# tmp_suffix:िगामी
# tmp_suffix:गामी
# tmp_suffix:ामी
# tmp_suffix:मी
# tmp_suffix:ी
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:61
#
# Suffix_del:ी
# ी ्
# not_dot ्
#
# final stiped word: प्रतिगाम्
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:्रतिगाम्
# tmp_suffix:रतिगाम्
# tmp_suffix:तिगाम्
# tmp_suffix:िगाम्
# tmp_suffix:गाम्
# tmp_suffix:ाम्
# tmp_suffix:म्
# tmp_suffix:्
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:प
# tmp_prefix:प्
# tmp_prefix:प्र
# tmp_prefix:प्रत
# tmp_prefix:प्रति
# tmp_prefix:प्रतिग
# tmp_prefix:प्रतिगा
# tmp_prefix:प्रतिगाम
# tmp_prefix:प्रतिगाम्
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):प्रतिगामी
#
# Unstemmed input token1388:विदेशी
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:िदेशी
# tmp_suffix:देशी
# tmp_suffix:ेशी
# tmp_suffix:शी
# tmp_suffix:ी
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:61
#
# Suffix_del:ी
# ी ्
# not_dot ्
#
# final stiped word: विदेश्
# Checking root word or not
# comdition3
# Checking root word or not
# comdition1
#
# Root word found:विदेश
#
# final stemmed token:विदेश
#
# Unstemmed input token1389:शक्ति
# Checking root word or not
# comdition1
#
# Root word found:शक्ति
#
# final stemmed token:शक्ति
#
# Unstemmed input token1390:घुस्ने
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ुस्ने
# tmp_suffix:स्ने
# tmp_suffix:्ने
# tmp_suffix:ने
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:16
#
# Suffix_del:ने
# ने .
#
# final stiped word: घुस्
# Checking root word or not
# comdition1
#
# Root word found:घुस्
#
# final stemmed token:घुस्
#
# Unstemmed input token1391:सबभन्दा
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:बभन्दा
# tmp_suffix:भन्दा
# tmp_suffix:न्दा
# tmp_suffix:्दा
# tmp_suffix:दा
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:18
#
# Suffix_del:ँदा
#
# Suffix_del:दा
# दा .
#
# final stiped word: सबभन्
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:बभन्
# tmp_suffix:भन्
# tmp_suffix:न्
# tmp_suffix:्
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:स
# tmp_prefix:सब
# tmp_prefix:सबभ
# tmp_prefix:सबभन
# tmp_prefix:सबभन्
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):सबभन्दा
#
# Unstemmed input token1392:सरल
# Checking root word or not
# comdition1
#
# Root word found:सरल
#
# final stemmed token:सरल
#
# Unstemmed input token1393:राजमार्ग
# Checking root word or not
# comdition1
#
# Root word found:राजमार्ग
#
# final stemmed token:राजमार्ग
#
# Unstemmed input token1394:सम्बन्धित
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:म्बन्धित
# tmp_suffix:्बन्धित
# tmp_suffix:बन्धित
# tmp_suffix:न्धित
# tmp_suffix:्धित
# tmp_suffix:धित
# tmp_suffix:ित
# tmp_suffix:त
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:स
# tmp_prefix:सम
# tmp_prefix:सम्
# tmp_prefix:सम्ब
# tmp_prefix:सम्बन
# tmp_prefix:सम्बन्
# tmp_prefix:सम्बन्ध
# tmp_prefix:सम्बन्धि
# tmp_prefix:सम्बन्धित
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):सम्बन्धित
#
# Unstemmed input token1395:क्षेत्रले
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:्षेत्रले
# tmp_suffix:षेत्रले
# tmp_suffix:ेत्रले
# tmp_suffix:त्रले
# tmp_suffix:्रले
# tmp_suffix:रले
# tmp_suffix:ले
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:3
#
# Suffix_del:ले
# ले .
#
# final stiped word: क्षेत्र
# Checking root word or not
# comdition1
#
# Root word found:क्षेत्र
#
# final stemmed token:क्षेत्र
#
# Unstemmed input token1396:बुझ्नु
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ुझ्नु
# tmp_suffix:झ्नु
# tmp_suffix:्नु
# tmp_suffix:नु
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:22
#
# Suffix_del:नु
# नु .
#
# final stiped word: बुझ्
# Checking root word or not
# comdition1
#
# Root word found:बुझ्
#
# final stemmed token:बुझ्
#
# Unstemmed input token1397:अनिवार्य
# Checking root word or not
# comdition1
#
# Root word found:अनिवार्य
#
# final stemmed token:अनिवार्य
#
# Unstemmed input token1398:त्यसलाई
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:्यसलाई
# tmp_suffix:यसलाई
# tmp_suffix:सलाई
# tmp_suffix:लाई
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:2
#
# Suffix_del:लाई
# लाई .
#
# final stiped word: त्यस
# Checking root word or not
# comdition1
#
# Root word found:त्यस
#
# final stemmed token:त्यस
#
# Unstemmed input token1399:बेलैमा
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ेलैमा
# tmp_suffix:लैमा
# tmp_suffix:ैमा
# tmp_suffix:मा
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:57
#
# Suffix_del:मा
# मा .
#
# final stiped word: बेलै
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ेलै
# tmp_suffix:लै
# tmp_suffix:ै
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:83
#
# Suffix_del:ै
# ै ्
# not_dot ्
#
# final stiped word: बेल्
# Checking root word or not
# comdition1
#
# Root word found:बेल्
#
# final stemmed token:बेल्
#
# Unstemmed input token1400:निराकरण
# Checking root word or not
# comdition1
#
# Root word found:निराकरण
#
# final stemmed token:निराकरण
#
# Unstemmed input token1401:पाइला
# Checking root word or not
# comdition1
#
# Root word found:पाइला
#
# final stemmed token:पाइला
#
# Unstemmed input token1402:चाल्नु
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:ाल्नु
# tmp_suffix:ल्नु
# tmp_suffix:्नु
# tmp_suffix:नु
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:22
#
# Suffix_del:नु
# नु .
#
# final stiped word: चाल्
# Checking root word or not
# comdition1
#
# Root word found:चाल्
#
# final stemmed token:चाल्
#
# Unstemmed input token1403:पर्दछ
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:र्दछ
# tmp_suffix:्दछ
# tmp_suffix:दछ
# tmp_suffix:छ
#
# suffix found
# comdition4
#
# Stripping suffix
# rule:7
#
# Suffix_del:ँछ
#
# Suffix_del:छ
# छ .
#
# final stiped word: पर्द
# Checking root word or not
#
# Checking suffix present or not
#
# tmp_suffix:र्द
# tmp_suffix:्द
# tmp_suffix:द
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:प
# tmp_prefix:पर
# tmp_prefix:पर्
# tmp_prefix:पर्द
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):पर्दछ
#
# Unstemmed input token1404:
#
# Checking root word or not
#
# Checking suffix present or not
#
#
# suffix not found
#
# Checking prefix present or not
#
# tmp_prefix:
#
#
# prefix not found
#
# Recombining suffix
# comdition7:unrecognized
#
# final token (couldnt stem):

# %%
len(unrecog)
# Out:
# 395

# %%
len(new)
# Out:
# 1404

# %%
m.getRoot()

# %%
new[0]

# %%
a="parot"
if a==("p"):
    print (a)

# %%
len(a)

# %%
a=a[:len(a)-1]

# %%
a

# %%
m.isRoot('धु')
m.setRoot('धु')

# %%
word="वर्षलाई"
word.replace("लाई","")

# %%
word
